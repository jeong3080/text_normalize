# %% [markdown]
# 코퍼스(corpus)(말뭉치)는 정형이나 비정형인 단어나 표현의 묶음이다. 모든 NLTK 코퍼스는 nltk.corpus 모듈에 저장되어 있다. 예를 들면 다음과 같다.
#
#
#
# ◼︎ gutenberg : <모비딕(Moby Dick)>이나 <성경> 등 구텐베르크 프로젝트(Gutenberg Project)에서 제공하는 영문 텍스트 18개
#
# ◼︎ names : 8000개의 남성과 여성의 이름 리스트
#
# ◼︎ words : 가장 빈번하게 사용하는 영어 단어 23만 5000개
#
# ◼︎ stopwords : 14개의 언어로 된 가장 많이 사용하는 불용어(stop word) 리스트. 영어로 된 리스트는 stop words.words("english")에 저장되어 있다. 불용어는 대부분의 분석에서 보통 삭제하는데, 텍스트 이해에 별로 기여하는 바가 없기 때문이다.
#
# ◼︎ cmudict : 카네기멜론대학교에서 만든 발음 사전으로 13만 4000개 입력 데이터가 있다. cmudict.entries()의 각 입력 데이터는 단어와 그 음절(syllables) 리스트의 튜플이다. 단어가 같더라도 다르게 발음할 수 있다. 이 코퍼스를 사용하면 발음이 같은 동음이의어(homophones)를 찾아볼 수 있다

# %% [markdown]
# from nltk.corpus import stopwords
# print(len(stopwords.words()))

# %%
from nltk.corpus import words
print(len(words.words()))
from nltk.corpus import names
print(len(names.words()))
# Out:
# 236736
# 7944

# %%
import requests 
from bs4 import BeautifulSoup 
dic8 = dict()
for search_query in tqdm(words.words()[200000:]):
    url = (f'http://aha-dic.com/View.asp?word={search_query}')
    res = requests.get(url) 
    soup = BeautifulSoup(res.text, "lxml")
    
    try:
        dic8[search_query] = soup.find_all("span", {"class": "phoneticKor"})[0].text.replace("[","").replace("]","")
    except:
        dic8[search_query] = ""
# Out:
# 100%|██████████| 36736/36736 [55:09<00:00, 11.10it/s]

# %% [markdown]
# import pickle
# with open("dic6.pkl","wb") as f:
#     pickle.dump(dic,f)

# %% [markdown]
# import pickle
# with open("dic1_6.pkl","wb") as f:
#     pickle.dump(dic8,f)

# %%
names.words()
# Out:
# ['Abagael',
#  'Abagail',
#  'Abbe',
#  'Abbey',
#  'Abbi',
#  'Abbie',
#  'Abby',
#  'Abigael',
#  'Abigail',
#  'Abigale',
#  'Abra',
#  'Acacia',
#  'Ada',
#  'Adah',
#  'Adaline',
#  'Adara',
#  'Addie',
#  'Addis',
#  'Adel',
#  'Adela',
#  'Adelaide',
#  'Adele',
#  'Adelice',
#  'Adelina',
#  'Adelind',
#  'Adeline',
#  'Adella',
#  'Adelle',
#  'Adena',
#  'Adey',
#  'Adi',
#  'Adiana',
#  'Adina',
#  'Adora',
#  'Adore',
#  'Adoree',
#  'Adorne',
#  'Adrea',
#  'Adria',
#  'Adriaens',
#  'Adrian',
#  'Adriana',
#  'Adriane',
#  'Adrianna',
#  'Adrianne',
#  'Adrien',
#  'Adriena',
#  'Adrienne',
#  'Aeriel',
#  'Aeriela',
#  'Aeriell',
#  'Ag',
#  'Agace',
#  'Agata',
#  'Agatha',
#  'Agathe',
#  'Aggi',
#  'Aggie',
#  'Aggy',
#  'Agna',
#  'Agnella',
#  'Agnes',
#  'Agnese',
#  'Agnesse',
#  'Agneta',
#  'Agnola',
#  'Agretha',
#  'Aida',
#  'Aidan',
#  'Aigneis',
#  'Aila',
#  'Aile',
#  'Ailee',
#  'Aileen',
#  'Ailene',
#  'Ailey',
#  'Aili',
#  'Ailina',
#  'Ailyn',
#  'Aime',
#  'Aimee',
#  'Aimil',
#  'Aina',
#  'Aindrea',
#  'Ainslee',
#  'Ainsley',
#  'Ainslie',
#  'Ajay',
#  'Alaine',
#  'Alameda',
#  'Alana',
#  'Alanah',
#  'Alane',
#  'Alanna',
#  'Alayne',
#  'Alberta',
#  'Albertina',
#  'Albertine',
#  'Albina',
#  'Alecia',
#  'Aleda',
#  'Aleece',
#  'Aleecia',
#  'Aleen',
#  'Alejandra',
#  'Alejandrina',
#  'Alena',
#  'Alene',
#  'Alessandra',
#  'Aleta',
#  'Alethea',
#  'Alex',
#  'Alexa',
#  'Alexandra',
#  'Alexandrina',
#  'Alexi',
#  'Alexia',
#  'Alexina',
#  'Alexine',
#  'Alexis',
#  'Alfie',
#  'Alfreda',
#  'Ali',
#  'Alia',
#  'Alica',
#  'Alice',
#  'Alicea',
#  'Alicia',
#  'Alida',
#  'Alidia',
#  'Alina',
#  'Aline',
#  'Alis',
#  'Alisa',
#  'Alisha',
#  'Alison',
#  'Alissa',
#  'Alisun',
#  'Alix',
#  'Aliza',
#  'Alla',
#  'Alleen',
#  'Allegra',
#  'Allene',
#  'Alli',
#  'Allianora',
#  'Allie',
#  'Allina',
#  'Allis',
#  'Allison',
#  'Allissa',
#  'Allsun',
#  'Ally',
#  'Allyce',
#  'Allyn',
#  'Allys',
#  'Allyson',
#  'Alma',
#  'Almeda',
#  'Almeria',
#  'Almeta',
#  'Almira',
#  'Almire',
#  'Aloise',
#  'Aloisia',
#  'Aloysia',
#  'Alpa',
#  'Alta',
#  'Althea',
#  'Alvera',
#  'Alvina',
#  'Alvinia',
#  'Alvira',
#  'Alyce',
#  'Alyda',
#  'Alys',
#  'Alysa',
#  'Alyse',
#  'Alysia',
#  'Alyson',
#  'Alyss',
#  'Alyssa',
#  'Amabel',
#  'Amabelle',
#  'Amalea',
#  'Amalee',
#  'Amaleta',
#  'Amalia',
#  'Amalie',
#  'Amalita',
#  'Amalle',
#  'Amanda',
#  'Amandi',
#  'Amandie',
#  'Amandy',
#  'Amara',
#  'Amargo',
#  'Amata',
#  'Amber',
#  'Amberly',
#  'Ambrosia',
#  'Ambur',
#  'Ame',
#  'Amelia',
#  'Amelie',
#  'Amelina',
#  'Ameline',
#  'Amelita',
#  'Ami',
#  'Amie',
#  'Amity',
#  'Ammamaria',
#  'Amy',
#  'Ana',
#  'Anabel',
#  'Anabella',
#  'Anabelle',
#  'Anais',
#  'Analiese',
#  'Analise',
#  'Anallese',
#  'Anallise',
#  'Anastasia',
#  'Anastasie',
#  'Anastassia',
#  'Anatola',
#  'Andee',
#  'Andi',
#  'Andie',
#  'Andra',
#  'Andrea',
#  'Andreana',
#  'Andree',
#  'Andrei',
#  'Andria',
#  'Andriana',
#  'Andriette',
#  'Andromache',
#  'Andromeda',
#  'Andy',
#  'Anestassia',
#  'Anet',
#  'Anett',
#  'Anetta',
#  'Anette',
#  'Ange',
#  'Angel',
#  'Angela',
#  'Angele',
#  'Angelia',
#  'Angelica',
#  'Angelika',
#  'Angelina',
#  'Angeline',
#  'Angelique',
#  'Angelita',
#  'Angelle',
#  'Angie',
#  'Angil',
#  'Angy',
#  'Ania',
#  'Anica',
#  'Anissa',
#  'Anita',
#  'Anitra',
#  'Anja',
#  'Anjanette',
#  'Anjela',
#  'Ann',
#  'Ann-Mari',
#  'Ann-Marie',
#  'Anna',
#  'Anna-Diana',
#  'Anna-Diane',
#  'Anna-Maria',
#  'Annabal',
#  'Annabel',
#  'Annabela',
#  'Annabell',
#  'Annabella',
#  'Annabelle',
#  'Annadiana',
#  'Annadiane',
#  'Annalee',
#  'Annalena',
#  'Annaliese',
#  'Annalisa',
#  'Annalise',
#  'Annalyse',
#  'Annamari',
#  'Annamaria',
#  'Annamarie',
#  'Anne',
#  'Anne-Corinne',
#  'Anne-Mar',
#  'Anne-Marie',
#  'Annecorinne',
#  'Anneliese',
#  'Annelise',
#  'Annemarie',
#  'Annetta',
#  'Annette',
#  'Anni',
#  'Annice',
#  'Annie',
#  'Annissa',
#  'Annmaria',
#  'Annmarie',
#  'Annnora',
#  'Annora',
#  'Anny',
#  'Anselma',
#  'Ansley',
#  'Anstice',
#  'Anthe',
#  'Anthea',
#  'Anthia',
#  'Antoinette',
#  'Antonella',
#  'Antonetta',
#  'Antonia',
#  'Antonie',
#  'Antonietta',
#  'Antonina',
#  'Anya',
#  'Aphrodite',
#  'Appolonia',
#  'April',
#  'Aprilette',
#  'Ara',
#  'Arabel',
#  'Arabela',
#  'Arabele',
#  'Arabella',
#  'Arabelle',
#  'Arda',
#  'Ardath',
#  'Ardeen',
#  'Ardelia',
#  'Ardelis',
#  'Ardella',
#  'Ardelle',
#  'Arden',
#  'Ardene',
#  'Ardenia',
#  'Ardine',
#  'Ardis',
#  'Ardith',
#  'Ardra',
#  'Ardyce',
#  'Ardys',
#  'Ardyth',
#  'Aretha',
#  'Ariadne',
#  'Ariana',
#  'Arianne',
#  'Aridatha',
#  'Ariel',
#  'Ariela',
#  'Ariella',
#  'Arielle',
#  'Arlana',
#  'Arlee',
#  'Arleen',
#  'Arlen',
#  'Arlena',
#  'Arlene',
#  'Arleta',
#  'Arlette',
#  'Arleyne',
#  'Arlie',
#  'Arliene',
#  'Arlina',
#  'Arlinda',
#  'Arline',
#  'Arly',
#  'Arlyn',
#  'Arlyne',
#  'Aryn',
#  'Ashely',
#  'Ashlee',
#  'Ashleigh',
#  'Ashlen',
#  'Ashley',
#  'Ashli',
#  'Ashlie',
#  'Ashly',
#  'Asia',
#  'Astra',
#  'Astrid',
#  'Astrix',
#  'Atalanta',
#  'Athena',
#  'Athene',
#  'Atlanta',
#  'Atlante',
#  'Auberta',
#  'Aubine',
#  'Aubree',
#  'Aubrette',
#  'Aubrey',
#  'Aubrie',
#  'Aubry',
#  'Audi',
#  'Audie',
#  'Audra',
#  'Audre',
#  'Audrey',
#  'Audrie',
#  'Audry',
#  'Audrye',
#  'Audy',
#  'Augusta',
#  'Auguste',
#  'Augustina',
#  'Augustine',
#  'Aura',
#  'Aurea',
#  'Aurel',
#  'Aurelea',
#  'Aurelia',
#  'Aurelie',
#  'Auria',
#  'Aurie',
#  'Aurilia',
#  'Aurlie',
#  'Auroora',
#  'Aurora',
#  'Aurore',
#  'Austin',
#  'Austina',
#  'Austine',
#  'Ava',
#  'Aveline',
#  'Averil',
#  'Averyl',
#  'Avie',
#  'Avis',
#  'Aviva',
#  'Avivah',
#  'Avril',
#  'Avrit',
#  'Ayn',
#  'Bab',
#  'Babara',
#  'Babette',
#  'Babita',
#  'Babs',
#  'Bambi',
#  'Bambie',
#  'Bamby',
#  'Barb',
#  'Barbabra',
#  'Barbara',
#  'Barbara-Anne',
#  'Barbaraanne',
#  'Barbe',
#  'Barbee',
#  'Barbette',
#  'Barbey',
#  'Barbi',
#  'Barbie',
#  'Barbra',
#  'Barby',
#  'Bari',
#  'Barrie',
#  'Barry',
#  'Basia',
#  'Bathsheba',
#  'Batsheva',
#  'Bea',
#  'Beatrice',
#  'Beatrisa',
#  'Beatrix',
#  'Beatriz',
#  'Beau',
#  'Bebe',
#  'Becca',
#  'Becka',
#  'Becki',
#  'Beckie',
#  'Becky',
#  'Bee',
#  'Beilul',
#  'Beitris',
#  'Bekki',
#  'Bel',
#  'Belia',
#  'Belicia',
#  'Belinda',
#  'Belita',
#  'Bell',
#  'Bella',
#  'Bellamy',
#  'Bellanca',
#  'Belle',
#  'Bellina',
#  'Belva',
#  'Belvia',
#  'Bendite',
#  'Benedetta',
#  'Benedicta',
#  'Benedikta',
#  'Benetta',
#  'Benita',
#  'Benni',
#  'Bennie',
#  'Benny',
#  'Benoite',
#  'Berenice',
#  'Beret',
#  'Berget',
#  'Berna',
#  'Bernadene',
#  'Bernadette',
#  'Bernadina',
#  'Bernadine',
#  'Bernardina',
#  'Bernardine',
#  'Bernelle',
#  'Bernete',
#  'Bernetta',
#  'Bernette',
#  'Berni',
#  'Bernice',
#  'Bernie',
#  'Bernita',
#  'Berny',
#  'Berri',
#  'Berrie',
#  'Berry',
#  'Bert',
#  'Berta',
#  'Berte',
#  'Bertha',
#  'Berthe',
#  'Berti',
#  'Bertie',
#  'Bertina',
#  'Bertine',
#  'Berty',
#  'Beryl',
#  'Beryle',
#  'Bess',
#  'Bessie',
#  'Bessy',
#  'Beth',
#  'Bethanne',
#  'Bethany',
#  'Bethena',
#  'Bethina',
#  'Betsey',
#  'Betsy',
#  'Betta',
#  'Bette',
#  'Bette-Ann',
#  'Betteann',
#  'Betteanne',
#  'Betti',
#  'Bettie',
#  'Bettina',
#  'Bettine',
#  'Betty',
#  'Bettye',
#  'Beulah',
#  'Bev',
#  'Beverie',
#  'Beverlee',
#  'Beverlie',
#  'Beverly',
#  'Bevvy',
#  'Bianca',
#  'Bianka',
#  'Biddy',
#  'Bidget',
#  'Bill',
#  'Billi',
#  'Billie',
#  'Billy',
#  'Binni',
#  'Binnie',
#  'Binny',
#  'Bird',
#  'Birdie',
#  'Birgit',
#  'Birgitta',
#  'Blair',
#  'Blaire',
#  'Blake',
#  'Blakelee',
#  'Blakeley',
#  'Blanca',
#  'Blanch',
#  'Blancha',
#  'Blanche',
#  'Blinni',
#  'Blinnie',
#  'Blinny',
#  'Bliss',
#  'Blisse',
#  'Blithe',
#  'Blondell',
#  'Blondelle',
#  'Blondie',
#  'Blondy',
#  'Blythe',
#  'Bo',
#  'Bobbette',
#  'Bobbi',
#  'Bobbie',
#  'Bobby',
#  'Bobette',
#  'Bobina',
#  'Bobine',
#  'Bobinette',
#  'Bonita',
#  'Bonnee',
#  'Bonni',
#  'Bonnie',
#  'Bonny',
#  'Brana',
#  'Brandais',
#  'Brande',
#  'Brandea',
#  'Brandi',
#  'Brandice',
#  'Brandie',
#  'Brandise',
#  'Brandy',
#  'Brea',
#  'Breanne',
#  'Brear',
#  'Bree',
#  'Breena',
#  'Bren',
#  'Brena',
#  'Brenda',
#  'Brenn',
#  'Brenna',
#  'Brett',
#  'Bria',
#  'Briana',
#  'Brianna',
#  'Brianne',
#  'Bride',
#  'Bridget',
#  'Bridgett',
#  'Bridgette',
#  'Bridie',
#  'Brier',
#  'Brietta',
#  'Brigid',
#  'Brigida',
#  'Brigit',
#  'Brigitta',
#  'Brigitte',
#  'Brina',
#  'Briney',
#  'Briny',
#  'Brit',
#  'Brita',
#  'Britaney',
#  'Britani',
#  'Briteny',
#  'Britney',
#  'Britni',
#  'Britt',
#  'Britta',
#  'Brittan',
#  'Brittany',
#  'Britte',
#  'Brittney',
#  'Brook',
#  'Brooke',
#  'Brooks',
#  'Brunella',
#  'Brunhilda',
#  'Brunhilde',
#  'Bryana',
#  'Bryn',
#  'Bryna',
#  'Brynn',
#  'Brynna',
#  'Brynne',
#  'Buffy',
#  'Bunni',
#  'Bunnie',
#  'Bunny',
#  'Burta',
#  'Cabrina',
#  'Cacilia',
#  'Cacilie',
#  'Caitlin',
#  'Caitrin',
#  'Cal',
#  'Calida',
#  'Calla',
#  'Calley',
#  'Calli',
#  'Callida',
#  'Callie',
#  'Cally',
#  'Calypso',
#  'Cam',
#  'Camala',
#  'Camel',
#  'Camella',
#  'Camellia',
#  'Cameo',
#  'Cami',
#  'Camila',
#  'Camile',
#  'Camilla',
#  'Camille',
#  'Cammi',
#  'Cammie',
#  'Cammy',
#  'Canada',
#  'Candace',
#  'Candi',
#  'Candice',
#  'Candida',
#  'Candide',
#  'Candie',
#  'Candis',
#  'Candra',
#  'Candy',
#  'Cappella',
#  'Caprice',
#  'Cara',
#  'Caralie',
#  'Caren',
#  'Carena',
#  'Caresa',
#  'Caressa',
#  'Caresse',
#  'Carey',
#  'Cari',
#  'Caria',
#  'Carie',
#  'Caril',
#  'Carilyn',
#  'Carin',
#  'Carina',
#  'Carine',
#  'Cariotta',
#  'Carissa',
#  'Carita',
#  'Caritta',
#  'Carla',
#  'Carlee',
#  'Carleen',
#  'Carlen',
#  'Carlena',
#  'Carlene',
#  'Carley',
#  'Carli',
#  'Carlie',
#  'Carlin',
#  'Carlina',
#  'Carline',
#  'Carlisle',
#  'Carlita',
#  'Carlota',
#  'Carlotta',
#  'Carly',
#  'Carlye',
#  'Carlyn',
#  'Carlynn',
#  'Carlynne',
#  'Carma',
#  'Carmel',
#  'Carmela',
#  'Carmelia',
#  'Carmelina',
#  'Carmelita',
#  'Carmella',
#  'Carmelle',
#  'Carmen',
#  'Carmina',
#  'Carmine',
#  'Carmita',
#  'Carmon',
#  'Caro',
#  'Carol',
#  'Carol-Jean',
#  'Carola',
#  'Carolan',
#  'Carolann',
#  'Carole',
#  'Carolee',
#  'Caroleen',
#  'Carolie',
#  'Carolin',
#  'Carolina',
#  'Caroline',
#  'Caroljean',
#  'Carolyn',
#  'Carolyne',
#  'Carolynn',
#  'Caron',
#  'Carree',
#  'Carri',
#  'Carrie',
#  'Carrissa',
#  'Carrol',
#  'Carroll',
#  'Carry',
#  'Cary',
#  'Caryl',
#  'Caryn',
#  'Casandra',
#  'Casey',
#  'Casi',
#  'Casia',
#  'Casie',
#  'Cass',
#  'Cassandra',
#  'Cassandre',
#  'Cassandry',
#  'Cassaundra',
#  'Cassey',
#  'Cassi',
#  'Cassie',
#  'Cassondra',
#  'Cassy',
#  'Cat',
#  'Catarina',
#  'Cate',
#  'Caterina',
#  'Catha',
#  'Catharina',
#  'Catharine',
#  'Cathe',
#  'Cathee',
#  'Catherin',
#  'Catherina',
#  'Catherine',
#  'Cathi',
#  'Cathie',
#  'Cathleen',
#  'Cathlene',
#  'Cathrin',
#  'Cathrine',
#  'Cathryn',
#  'Cathy',
#  'Cathyleen',
#  'Cati',
#  'Catie',
#  'Catina',
#  'Catlaina',
#  'Catlee',
#  'Catlin',
#  'Catrina',
#  'Catriona',
#  'Caty',
#  'Cayla',
#  'Cecelia',
#  'Cecil',
#  'Cecile',
#  'Ceciley',
#  'Cecilia',
#  'Cecilla',
#  'Cecily',
#  'Ceil',
#  'Cele',
#  'Celene',
#  'Celesta',
#  'Celeste',
#  'Celestia',
#  'Celestina',
#  'Celestine',
#  'Celestyn',
#  'Celestyna',
#  'Celia',
#  'Celie',
#  'Celina',
#  'Celinda',
#  'Celine',
#  'Celinka',
#  'Celisse',
#  'Celle',
#  'Cesya',
#  'Chad',
#  'Chanda',
#  'Chandal',
#  'Chandra',
#  'Channa',
#  'Chantal',
#  'Chantalle',
#  'Charil',
#  'Charin',
#  'Charis',
#  'Charissa',
#  'Charisse',
#  'Charita',
#  'Charity',
#  'Charla',
#  'Charlean',
#  'Charleen',
#  'Charlena',
#  'Charlene',
#  'Charline',
#  'Charlot',
#  'Charlott',
#  'Charlotta',
#  'Charlotte',
#  'Charmain',
#  'Charmaine',
#  'Charmane',
#  'Charmian',
#  'Charmine',
#  'Charmion',
#  'Charo',
#  'Charyl',
#  'Chastity',
#  'Chelsae',
#  'Chelsea',
#  'Chelsey',
#  'Chelsie',
#  'Chelsy',
#  'Cher',
#  'Chere',
#  'Cherey',
#  'Cheri',
#  'Cherianne',
#  'Cherice',
#  'Cherida',
#  'Cherie',
#  'Cherilyn',
#  'Cherilynn',
#  'Cherin',
#  'Cherise',
#  'Cherish',
#  'Cherlyn',
#  'Cherri',
#  'Cherrita',
#  'Cherry',
#  'Chery',
#  'Cherye',
#  'Cheryl',
#  'Cheslie',
#  'Chiarra',
#  'Chickie',
#  'Chicky',
#  'Chiquita',
#  'Chloe',
#  'Chloette',
#  'Chloris',
#  'Chris',
#  'Chriss',
#  'Chrissa',
#  'Chrissie',
#  'Chrissy',
#  'Christa',
#  'Christabel',
#  'Christabella',
#  'Christabelle',
#  'Christal',
#  'Christalle',
#  'Christan',
#  'Christean',
#  'Christel',
#  'Christen',
#  'Christi',
#  'Christian',
#  'Christiana',
#  'Christiane',
#  'Christie',
#  'Christin',
#  'Christina',
#  'Christine',
#  'Christy',
#  'Christyna',
#  'Chrysa',
#  'Chrysler',
#  'Chrystal',
#  'Chryste',
#  'Chrystel',
#  'Ciara',
#  'Cicely',
#  'Cicily',
#  'Ciel',
#  'Cilka',
#  'Cinda',
#  'Cindee',
#  'Cindelyn',
#  'Cinderella',
#  'Cindi',
#  'Cindie',
#  'Cindra',
#  'Cindy',
#  'Cinnamon',
#  'Cissie',
#  'Cissy',
#  'Clair',
#  'Claire',
#  'Clara',
#  'Clarabelle',
#  'Clare',
#  ...]

# %%
import requests 
from bs4 import BeautifulSoup 
dic9 = dict()
for search_query in tqdm(names.words()):
    url = (f'http://aha-dic.com/View.asp?word={search_query}')
    res = requests.get(url) 
    soup = BeautifulSoup(res.text, "lxml")
    
    try:
        dic8[search_query] = soup.find_all("span", {"class": "phoneticKor"})[0].text.replace("[","").replace("]","")
    except:
        dic8[search_query] = ""
# Out:
# 100%|██████████| 7944/7944 [07:21<00:00, 17.98it/s]

# %%
for i in tqdm(names.words()):
    dic9[i] = dic8[i]
# Out:
# 100%|██████████| 7944/7944 [00:00<00:00, 3724519.45it/s]

# %% [markdown]
# import pickle
# with open("dic3.pkl","wb") as f:
#     pickle.dump(dic9,f)

# %%
dic9
# Out:
# {'Abagael': '',
#  'Abagail': '',
#  'Abbe': '앱에이',
#  'Abbey': '애비',
#  'Abbi': '',
#  'Abbie': '',
#  'Abby': '',
#  'Abigael': '',
#  'Abigail': '애버게일',
#  'Abigale': '',
#  'Abra': '',
#  'Acacia': '어케이셔',
#  'Ada': '',
#  'Adah': '',
#  'Adaline': '애덜린',
#  'Adara': '',
#  'Addie': '애디',
#  'Addis': '',
#  'Adel': '',
#  'Adela': '',
#  'Adelaide': '애덜레이드',
#  'Adele': '',
#  'Adelice': '',
#  'Adelina': '',
#  'Adelind': '',
#  'Adeline': '',
#  'Adella': '',
#  'Adelle': '',
#  'Adena': '',
#  'Adey': '',
#  'Adi': '',
#  'Adiana': '',
#  'Adina': '',
#  'Adora': '',
#  'Adore': '어도',
#  'Adoree': '',
#  'Adorne': '',
#  'Adrea': '',
#  'Adria': '',
#  'Adriaens': '',
#  'Adrian': '에이드리언',
#  'Adriana': '',
#  'Adriane': '',
#  'Adrianna': '',
#  'Adrianne': '',
#  'Adrien': '',
#  'Adriena': '',
#  'Adrienne': '',
#  'Aeriel': '',
#  'Aeriela': '',
#  'Aeriell': '',
#  'Ag': '',
#  'Agace': '',
#  'Agata': '',
#  'Agatha': '애거써',
#  'Agathe': '',
#  'Aggi': '',
#  'Aggie': '애기',
#  'Aggy': '',
#  'Agna': '',
#  'Agnella': '',
#  'Agnes': '애그니스',
#  'Agnese': '',
#  'Agnesse': '',
#  'Agneta': '',
#  'Agnola': '',
#  'Agretha': '',
#  'Aida': '에이더',
#  'Aidan': '',
#  'Aigneis': '',
#  'Aila': '',
#  'Aile': '',
#  'Ailee': '',
#  'Aileen': '에일린',
#  'Ailene': '',
#  'Ailey': '',
#  'Aili': '',
#  'Ailina': '',
#  'Ailyn': '',
#  'Aime': '',
#  'Aimee': '',
#  'Aimil': '',
#  'Aina': '',
#  'Aindrea': '',
#  'Ainslee': '',
#  'Ainsley': '',
#  'Ainslie': '',
#  'Ajay': '',
#  'Alaine': '',
#  'Alameda': '앨러미더',
#  'Alana': '',
#  'Alanah': '',
#  'Alane': '',
#  'Alanna': '',
#  'Alayne': '',
#  'Alberta': '앨버터',
#  'Albertina': '',
#  'Albertine': '',
#  'Albina': '앨바이너',
#  'Alecia': '',
#  'Aleda': '',
#  'Aleece': '',
#  'Aleecia': '',
#  'Aleen': '',
#  'Alejandra': '',
#  'Alejandrina': '',
#  'Alena': '',
#  'Alene': '',
#  'Alessandra': '',
#  'Aleta': '',
#  'Alethea': '',
#  'Alex': '앨릭스',
#  'Alexa': '',
#  'Alexandra': '앨리그잰드러',
#  'Alexandrina': '',
#  'Alexi': '',
#  'Alexia': '얼렉시어',
#  'Alexina': '',
#  'Alexine': '',
#  'Alexis': '',
#  'Alfie': '',
#  'Alfreda': '',
#  'Ali': '',
#  'Alia': '',
#  'Alica': '',
#  'Alice': '앨리스',
#  'Alicea': '',
#  'Alicia': '',
#  'Alida': '',
#  'Alidia': '',
#  'Alina': '',
#  'Aline': '얼라인',
#  'Alis': '',
#  'Alisa': '',
#  'Alisha': '',
#  'Alison': '앨리선',
#  'Alissa': '',
#  'Alisun': '',
#  'Alix': '',
#  'Aliza': '',
#  'Alla': '',
#  'Alleen': '',
#  'Allegra': '',
#  'Allene': '',
#  'Alli': '',
#  'Allianora': '',
#  'Allie': '',
#  'Allina': '',
#  'Allis': '',
#  'Allison': '',
#  'Allissa': '',
#  'Allsun': '',
#  'Ally': '얼라이',
#  'Allyce': '',
#  'Allyn': '',
#  'Allys': '',
#  'Allyson': '',
#  'Alma': '앨머',
#  'Almeda': '',
#  'Almeria': '',
#  'Almeta': '',
#  'Almira': '',
#  'Almire': '',
#  'Aloise': '',
#  'Aloisia': '',
#  'Aloysia': '',
#  'Alpa': '',
#  'Alta': '',
#  'Althea': '앨씨어',
#  'Alvera': '',
#  'Alvina': '',
#  'Alvinia': '',
#  'Alvira': '',
#  'Alyce': '',
#  'Alyda': '',
#  'Alys': '',
#  'Alysa': '',
#  'Alyse': '',
#  'Alysia': '',
#  'Alyson': '',
#  'Alyss': '',
#  'Alyssa': '',
#  'Amabel': '',
#  'Amabelle': '',
#  'Amalea': '',
#  'Amalee': '',
#  'Amaleta': '',
#  'Amalia': '',
#  'Amalie': '',
#  'Amalita': '',
#  'Amalle': '',
#  'Amanda': '어맨더',
#  'Amandi': '',
#  'Amandie': '',
#  'Amandy': '',
#  'Amara': '',
#  'Amargo': '',
#  'Amata': '',
#  'Amber': '앰버',
#  'Amberly': '',
#  'Ambrosia': '앰브로저',
#  'Ambur': '',
#  'Ame': '',
#  'Amelia': '어멜리어',
#  'Amelie': '',
#  'Amelina': '',
#  'Ameline': '',
#  'Amelita': '',
#  'Ami': '아미',
#  'Amie': '아미',
#  'Amity': '애머티',
#  'Ammamaria': '',
#  'Amy': '에이미',
#  'Ana': '에이너',
#  'Anabel': '',
#  'Anabella': '',
#  'Anabelle': '',
#  'Anais': '',
#  'Analiese': '',
#  'Analise': '',
#  'Anallese': '',
#  'Anallise': '',
#  'Anastasia': '애너스테이저',
#  'Anastasie': '',
#  'Anastassia': '',
#  'Anatola': '',
#  'Andee': '',
#  'Andi': '',
#  'Andie': '',
#  'Andra': '',
#  'Andrea': '',
#  'Andreana': '',
#  'Andree': '',
#  'Andrei': '',
#  'Andria': '',
#  'Andriana': '',
#  'Andriette': '',
#  'Andromache': '앤드라머키',
#  'Andromeda': '앤드라미더',
#  'Andy': '',
#  'Anestassia': '',
#  'Anet': '',
#  'Anett': '',
#  'Anetta': '',
#  'Anette': '',
#  'Ange': '',
#  'Angel': '에인절',
#  'Angela': '앤절러',
#  'Angele': '',
#  'Angelia': '',
#  'Angelica': '앤젤리커',
#  'Angelika': '',
#  'Angelina': '앤절리너',
#  'Angeline': '',
#  'Angelique': '',
#  'Angelita': '',
#  'Angelle': '',
#  'Angie': '',
#  'Angil': '',
#  'Angy': '',
#  'Ania': '',
#  'Anica': '',
#  'Anissa': '',
#  'Anita': '어니터',
#  'Anitra': '',
#  'Anja': '',
#  'Anjanette': '',
#  'Anjela': '',
#  'Ann': '',
#  'Ann-Mari': '',
#  'Ann-Marie': '',
#  'Anna': '아너',
#  'Anna-Diana': '',
#  'Anna-Diane': '',
#  'Anna-Maria': '',
#  'Annabal': '',
#  'Annabel': '애너벨',
#  'Annabela': '',
#  'Annabell': '',
#  'Annabella': '',
#  'Annabelle': '',
#  'Annadiana': '',
#  'Annadiane': '',
#  'Annalee': '',
#  'Annalena': '',
#  'Annaliese': '',
#  'Annalisa': '',
#  'Annalise': '',
#  'Annalyse': '',
#  'Annamari': '',
#  'Annamaria': '',
#  'Annamarie': '',
#  'Anne': '앤',
#  'Anne-Corinne': '',
#  'Anne-Mar': '',
#  'Anne-Marie': '',
#  'Annecorinne': '',
#  'Anneliese': '',
#  'Annelise': '',
#  'Annemarie': '',
#  'Annetta': '',
#  'Annette': '',
#  'Anni': '',
#  'Annice': '',
#  'Annie': '',
#  'Annissa': '',
#  'Annmaria': '',
#  'Annmarie': '',
#  'Annnora': '',
#  'Annora': '',
#  'Anny': '',
#  'Anselma': '',
#  'Ansley': '',
#  'Anstice': '',
#  'Anthe': '',
#  'Anthea': '앤씨어',
#  'Anthia': '',
#  'Antoinette': '앤트워넷',
#  'Antonella': '',
#  'Antonetta': '',
#  'Antonia': '앤토니어',
#  'Antonie': '',
#  'Antonietta': '',
#  'Antonina': '',
#  'Anya': '',
#  'Aphrodite': '애프러다이티',
#  'Appolonia': '',
#  'April': '에이프럴',
#  'Aprilette': '',
#  'Ara': '에이러',
#  'Arabel': '',
#  'Arabela': '',
#  'Arabele': '',
#  'Arabella': '',
#  'Arabelle': '',
#  'Arda': '',
#  'Ardath': '',
#  'Ardeen': '',
#  'Ardelia': '',
#  'Ardelis': '',
#  'Ardella': '',
#  'Ardelle': '',
#  'Arden': '아든',
#  'Ardene': '',
#  'Ardenia': '',
#  'Ardine': '',
#  'Ardis': '',
#  'Ardith': '',
#  'Ardra': '',
#  'Ardyce': '',
#  'Ardys': '',
#  'Ardyth': '',
#  'Aretha': '',
#  'Ariadne': '애리애드니',
#  'Ariana': '',
#  'Arianne': '',
#  'Aridatha': '',
#  'Ariel': '에어리얼',
#  'Ariela': '',
#  'Ariella': '',
#  'Arielle': '',
#  'Arlana': '',
#  'Arlee': '',
#  'Arleen': '',
#  'Arlen': '',
#  'Arlena': '',
#  'Arlene': '',
#  'Arleta': '',
#  'Arlette': '',
#  'Arleyne': '',
#  'Arlie': '',
#  'Arliene': '',
#  'Arlina': '',
#  'Arlinda': '',
#  'Arline': '',
#  'Arly': '',
#  'Arlyn': '',
#  'Arlyne': '',
#  'Aryn': '',
#  'Ashely': '',
#  'Ashlee': '',
#  'Ashleigh': '',
#  'Ashlen': '',
#  'Ashley': '',
#  'Ashli': '',
#  'Ashlie': '',
#  'Ashly': '',
#  'Asia': '에이저',
#  'Astra': '',
#  'Astrid': '',
#  'Astrix': '',
#  'Atalanta': '애털랜터',
#  'Athena': '어씨너',
#  'Athene': '어씨니',
#  'Atlanta': '애틀랜터',
#  'Atlante': '',
#  'Auberta': '',
#  'Aubine': '',
#  'Aubree': '',
#  'Aubrette': '',
#  'Aubrey': '오브리',
#  'Aubrie': '',
#  'Aubry': '',
#  'Audi': '',
#  'Audie': '',
#  'Audra': '',
#  'Audre': '',
#  'Audrey': '오드리',
#  'Audrie': '',
#  'Audry': '',
#  'Audrye': '',
#  'Audy': '',
#  'Augusta': '오거스터',
#  'Auguste': '',
#  'Augustina': '',
#  'Augustine': '오거스틴',
#  'Aura': '오러',
#  'Aurea': '',
#  'Aurel': '',
#  'Aurelea': '',
#  'Aurelia': '오릴리어',
#  'Aurelie': '',
#  'Auria': '',
#  'Aurie': '',
#  'Aurilia': '',
#  'Aurlie': '',
#  'Auroora': '',
#  'Aurora': '오로러',
#  'Aurore': '',
#  'Austin': '오스턴',
#  'Austina': '',
#  'Austine': '',
#  'Ava': '어바',
#  'Aveline': '',
#  'Averil': '',
#  'Averyl': '',
#  'Avie': '',
#  'Avis': '에이비스',
#  'Aviva': '',
#  'Avivah': '',
#  'Avril': '',
#  'Avrit': '',
#  'Ayn': '',
#  'Bab': '밥',
#  'Babara': '',
#  'Babette': '',
#  'Babita': '',
#  'Babs': '',
#  'Bambi': '',
#  'Bambie': '',
#  'Bamby': '',
#  'Barb': '바브',
#  'Barbabra': '',
#  'Barbara': '바버러',
#  'Barbara-Anne': '',
#  'Barbaraanne': '',
#  'Barbe': '',
#  'Barbee': '',
#  'Barbette': '바벳',
#  'Barbey': '',
#  'Barbi': '',
#  'Barbie': '',
#  'Barbra': '',
#  'Barby': '',
#  'Bari': '바리',
#  'Barrie': '배리',
#  'Barry': '바리',
#  'Basia': '',
#  'Bathsheba': '배쓰쉬버',
#  'Batsheva': '',
#  'Bea': '',
#  'Beatrice': '비어트리스',
#  'Beatrisa': '',
#  'Beatrix': '',
#  'Beatriz': '',
#  'Beau': '보',
#  'Bebe': '',
#  'Becca': '',
#  'Becka': '',
#  'Becki': '',
#  'Beckie': '',
#  'Becky': '베키',
#  'Bee': '비',
#  'Beilul': '',
#  'Beitris': '',
#  'Bekki': '',
#  'Bel': '벨',
#  'Belia': '',
#  'Belicia': '',
#  'Belinda': '벌린더',
#  'Belita': '',
#  'Bell': '벨',
#  'Bella': '벨러',
#  'Bellamy': '',
#  'Bellanca': '',
#  'Belle': '벨',
#  'Bellina': '',
#  'Belva': '',
#  'Belvia': '',
#  'Bendite': '',
#  'Benedetta': '',
#  'Benedicta': '',
#  'Benedikta': '',
#  'Benetta': '',
#  'Benita': '',
#  'Benni': '베니',
#  'Bennie': '베니',
#  'Benny': '베니',
#  'Benoite': '',
#  'Berenice': '',
#  'Beret': '버레이',
#  'Berget': '',
#  'Berna': '',
#  'Bernadene': '',
#  'Bernadette': '버너뎃',
#  'Bernadina': '',
#  'Bernadine': '',
#  'Bernardina': '',
#  'Bernardine': '버너딘',
#  'Bernelle': '',
#  'Bernete': '',
#  'Bernetta': '',
#  'Bernette': '',
#  'Berni': '',
#  'Bernice': '',
#  'Bernie': '',
#  'Bernita': '',
#  'Berny': '',
#  'Berri': '',
#  'Berrie': '',
#  'Berry': '베리',
#  'Bert': '버트',
#  'Berta': '',
#  'Berte': '',
#  'Bertha': '버써',
#  'Berthe': '',
#  'Berti': '',
#  'Bertie': '버티',
#  'Bertina': '',
#  'Bertine': '',
#  'Berty': '버티',
#  'Beryl': '베럴',
#  'Beryle': '',
#  'Bess': '',
#  'Bessie': '베시',
#  'Bessy': '',
#  'Beth': '베이쓰',
#  'Bethanne': '',
#  'Bethany': '베써니',
#  'Bethena': '',
#  'Bethina': '',
#  'Betsey': '',
#  'Betsy': '베치',
#  'Betta': '베터',
#  'Bette': '',
#  'Bette-Ann': '',
#  'Betteann': '',
#  'Betteanne': '',
#  'Betti': '',
#  'Bettie': '',
#  'Bettina': '',
#  'Bettine': '',
#  'Betty': '베티',
#  'Bettye': '',
#  'Beulah': '뷸러',
#  'Bev': '',
#  'Beverie': '',
#  'Beverlee': '',
#  'Beverlie': '',
#  'Beverly': '',
#  'Bevvy': '베비',
#  'Bianca': '',
#  'Bianka': '',
#  'Biddy': '비디',
#  'Bidget': '',
#  'Bill': '빌',
#  'Billi': '',
#  'Billie': '빌리',
#  'Billy': '빌리',
#  'Binni': '',
#  'Binnie': '',
#  'Binny': '',
#  'Bird': '버드',
#  'Birdie': '버디',
#  'Birgit': '',
#  'Birgitta': '',
#  'Blair': '',
#  'Blaire': '',
#  'Blake': '블레이크',
#  'Blakelee': '',
#  'Blakeley': '',
#  'Blanca': '',
#  'Blanch': '블랜치',
#  'Blancha': '',
#  'Blanche': '블랜치',
#  'Blinni': '',
#  'Blinnie': '',
#  'Blinny': '',
#  'Bliss': '블리스',
#  'Blisse': '',
#  'Blithe': '블라이드',
#  'Blondell': '',
#  'Blondelle': '',
#  'Blondie': '블란디',
#  'Blondy': '',
#  'Blythe': '',
#  'Bo': '',
#  'Bobbette': '',
#  'Bobbi': '',
#  'Bobbie': '바비',
#  'Bobby': '바비',
#  'Bobette': '',
#  'Bobina': '',
#  'Bobine': '',
#  'Bobinette': '',
#  'Bonita': '',
#  'Bonnee': '',
#  'Bonni': '',
#  'Bonnie': '',
#  'Bonny': '바니',
#  'Brana': '',
#  'Brandais': '',
#  'Brande': '',
#  'Brandea': '',
#  'Brandi': '',
#  'Brandice': '',
#  'Brandie': '',
#  'Brandise': '',
#  'Brandy': '브랜디',
#  'Brea': '',
#  'Breanne': '',
#  'Brear': '',
#  'Bree': '브리',
#  'Breena': '',
#  'Bren': '브렌',
#  'Brena': '',
#  'Brenda': '브렌더',
#  'Brenn': '',
#  'Brenna': '',
#  'Brett': '',
#  'Bria': '',
#  'Briana': '',
#  'Brianna': '',
#  'Brianne': '',
#  'Bride': '브라이드',
#  'Bridget': '브리짓',
#  'Bridgett': '',
#  'Bridgette': '',
#  'Bridie': '',
#  'Brier': '브라이어',
#  'Brietta': '',
#  'Brigid': '브리지드',
#  'Brigida': '',
#  'Brigit': '',
#  'Brigitta': '',
#  'Brigitte': '',
#  'Brina': '',
#  'Briney': '',
#  'Briny': '브라이니',
#  'Brit': '브릿',
#  'Brita': '',
#  'Britaney': '',
#  'Britani': '',
#  'Briteny': '',
#  'Britney': '',
#  'Britni': '',
#  'Britt': '브릿',
#  'Britta': '',
#  'Brittan': '',
#  'Brittany': '브리터니',
#  'Britte': '',
#  'Brittney': '',
#  'Brook': '브룩',
#  'Brooke': '브룩',
#  'Brooks': '',
#  'Brunella': '',
#  'Brunhilda': '',
#  'Brunhilde': '',
#  'Bryana': '',
#  'Bryn': '',
#  'Bryna': '',
#  'Brynn': '',
#  'Brynna': '',
#  'Brynne': '',
#  'Buffy': '버피',
#  'Bunni': '',
#  'Bunnie': '',
#  'Bunny': '버니',
#  'Burta': '',
#  'Cabrina': '',
#  'Cacilia': '',
#  'Cacilie': '',
#  'Caitlin': '',
#  'Caitrin': '',
#  'Cal': '',
#  'Calida': '',
#  'Calla': '캘러',
#  'Calley': '',
#  'Calli': '',
#  'Callida': '',
#  'Callie': '',
#  'Cally': '',
#  'Calypso': '컬립소',
#  'Cam': '캠',
#  'Camala': '',
#  'Camel': '캐멀',
#  'Camella': '',
#  'Camellia': '커밀리어',
#  'Cameo': '캐미오',
#  'Cami': '',
#  'Camila': '',
#  'Camile': '',
#  'Camilla': '커밀러',
#  'Camille': '',
#  'Cammi': '',
#  'Cammie': '',
#  'Cammy': '',
#  'Canada': '캐너더',
#  'Candace': '',
#  'Candi': '',
#  'Candice': '',
#  'Candida': '캔디더',
#  'Candide': '',
#  'Candie': '',
#  'Candis': '',
#  'Candra': '',
#  'Candy': '캔디',
#  'Cappella': '',
#  'Caprice': '커프리스',
#  'Cara': '',
#  'Caralie': '',
#  'Caren': '',
#  'Carena': '',
#  'Caresa': '',
#  'Caressa': '',
#  'Caresse': '',
#  'Carey': '',
#  'Cari': '',
#  'Caria': '케어리어',
#  'Carie': '',
#  'Caril': '',
#  'Carilyn': '',
#  'Carin': '',
#  'Carina': '커라이너',
#  'Carine': '',
#  'Cariotta': '',
#  'Carissa': '',
#  'Carita': '',
#  'Caritta': '',
#  'Carla': '',
#  'Carlee': '',
#  'Carleen': '',
#  'Carlen': '',
#  'Carlena': '',
#  'Carlene': '',
#  'Carley': '',
#  'Carli': '',
#  'Carlie': '',
#  'Carlin': '칼린',
#  'Carlina': '',
#  'Carline': '칼린',
#  'Carlisle': '칼라일',
#  'Carlita': '',
#  'Carlota': '칼라터',
#  'Carlotta': '',
#  'Carly': '',
#  'Carlye': '',
#  'Carlyn': '',
#  'Carlynn': '',
#  'Carlynne': '',
#  'Carma': '',
#  'Carmel': '카멀',
#  'Carmela': '',
#  'Carmelia': '',
#  'Carmelina': '',
#  'Carmelita': '',
#  'Carmella': '',
#  'Carmelle': '',
#  'Carmen': '카먼',
#  'Carmina': '',
#  'Carmine': '카민',
#  'Carmita': '',
#  'Carmon': '',
#  'Caro': '',
#  'Carol': '캐럴',
#  'Carol-Jean': '',
#  'Carola': '',
#  'Carolan': '',
#  'Carolann': '',
#  'Carole': '',
#  'Carolee': '',
#  'Caroleen': '',
#  'Carolie': '',
#  'Carolin': '',
#  'Carolina': '캐럴라이너',
#  'Caroline': '캐럴라인',
#  'Caroljean': '',
#  'Carolyn': '',
#  'Carolyne': '',
#  'Carolynn': '',
#  'Caron': '',
#  'Carree': '',
#  'Carri': '',
#  'Carrie': '캐리',
#  'Carrissa': '',
#  'Carrol': '',
#  'Carroll': '캐럴',
#  'Carry': '캐리',
#  'Cary': '',
#  'Caryl': '',
#  'Caryn': '',
#  'Casandra': '',
#  'Casey': '',
#  'Casi': '',
#  'Casia': '',
#  'Casie': '',
#  'Cass': '캐스',
#  'Cassandra': '커샌드러',
#  'Cassandre': '',
#  'Cassandry': '',
#  'Cassaundra': '',
#  'Cassey': '',
#  'Cassi': '',
#  'Cassie': '캐시',
#  'Cassondra': '',
#  'Cassy': '',
#  'Cat': '캣',
#  'Catarina': '',
#  'Cate': '케이트',
#  'Caterina': '',
#  'Catha': '',
#  'Catharina': '캐써라이너',
#  'Catharine': '',
#  'Cathe': '',
#  'Cathee': '',
#  'Catherin': '',
#  'Catherina': '캐써라이너',
#  'Catherine': '캐써린',
#  'Cathi': '',
#  'Cathie': '',
#  'Cathleen': '',
#  'Cathlene': '',
#  'Cathrin': '',
#  'Cathrine': '',
#  'Cathryn': '',
#  'Cathy': '캐씨',
#  'Cathyleen': '',
#  'Cati': '',
#  'Catie': '',
#  'Catina': '',
#  'Catlaina': '',
#  'Catlee': '',
#  'Catlin': '',
#  'Catrina': '',
#  'Catriona': '',
#  'Caty': '',
#  'Cayla': '',
#  'Cecelia': '',
#  'Cecil': '시설',
#  'Cecile': '시실',
#  'Ceciley': '',
#  'Cecilia': '시실리어',
#  'Cecilla': '',
#  'Cecily': '세설리',
#  'Ceil': '실',
#  'Cele': '',
#  'Celene': '',
#  'Celesta': '설레스터',
#  'Celeste': '설레스트',
#  'Celestia': '',
#  'Celestina': '',
#  'Celestine': '셀러스타인',
#  'Celestyn': '',
#  'Celestyna': '',
#  'Celia': '실리어',
#  'Celie': '',
#  'Celina': '',
#  'Celinda': '',
#  'Celine': '',
#  'Celinka': '',
#  'Celisse': '',
#  'Celle': '',
#  'Cesya': '',
#  'Chad': '채드',
#  'Chanda': '',
#  'Chandal': '',
#  'Chandra': '',
#  'Channa': '',
#  'Chantal': '',
#  'Chantalle': '',
#  'Charil': '',
#  'Charin': '',
#  'Charis': '',
#  'Charissa': '',
#  'Charisse': '',
#  'Charita': '',
#  'Charity': '채러티',
#  'Charla': '',
#  'Charlean': '',
#  'Charleen': '',
#  'Charlena': '',
#  'Charlene': '',
#  'Charline': '',
#  'Charlot': '',
#  'Charlott': '',
#  'Charlotta': '',
#  'Charlotte': '샬럿',
#  'Charmain': '',
#  'Charmaine': '',
#  'Charmane': '',
#  'Charmian': '',
#  'Charmine': '',
#  'Charmion': '',
#  'Charo': '',
#  'Charyl': '',
#  'Chastity': '채스터티',
#  'Chelsae': '',
#  'Chelsea': '첼시',
#  'Chelsey': '',
#  'Chelsie': '',
#  'Chelsy': '',
#  'Cher': '쉐어',
#  'Chere': '',
#  'Cherey': '',
#  'Cheri': '',
#  'Cherianne': '',
#  'Cherice': '',
#  'Cherida': '',
#  'Cherie': '',
#  'Cherilyn': '',
#  'Cherilynn': '',
#  'Cherin': '',
#  'Cherise': '',
#  'Cherish': '체리쉬',
#  'Cherlyn': '',
#  'Cherri': '',
#  'Cherrita': '',
#  'Cherry': '체리',
#  'Chery': '',
#  'Cherye': '',
#  'Cheryl': '',
#  'Cheslie': '',
#  'Chiarra': '',
#  'Chickie': '',
#  'Chicky': '',
#  'Chiquita': '',
#  'Chloe': '클로이',
#  'Chloette': '',
#  'Chloris': '',
#  'Chris': '크리스',
#  'Chriss': '',
#  'Chrissa': '',
#  'Chrissie': '크리시',
#  'Chrissy': '',
#  'Christa': '',
#  'Christabel': '',
#  'Christabella': '',
#  'Christabelle': '',
#  'Christal': '',
#  'Christalle': '',
#  'Christan': '',
#  'Christean': '',
#  'Christel': '',
#  'Christen': '크리슨',
#  'Christi': '',
#  'Christian': '크리스천',
#  'Christiana': '크리스티애너',
#  'Christiane': '',
#  'Christie': '크리스티',
#  'Christin': '',
#  'Christina': '크리스티너',
#  'Christine': '크리스틴',
#  'Christy': '크리스티',
#  'Christyna': '',
#  'Chrysa': '',
#  'Chrysler': '크라이슬러',
#  'Chrystal': '',
#  'Chryste': '',
#  'Chrystel': '',
#  'Ciara': '',
#  'Cicely': '시설리',
#  'Cicily': '',
#  'Ciel': '',
#  'Cilka': '',
#  'Cinda': '',
#  'Cindee': '',
#  'Cindelyn': '',
#  'Cinderella': '신더렐러',
#  'Cindi': '',
#  'Cindie': '',
#  'Cindra': '',
#  'Cindy': '',
#  'Cinnamon': '시너먼',
#  'Cissie': '',
#  'Cissy': '시시',
#  'Clair': '클레어',
#  'Claire': '클레어',
#  'Clara': '클레어러',
#  'Clarabelle': '',
#  'Clare': '클레어',
#  ...}

# %%
Counter(dic9.values())
# Out:
# Counter({'': 5653,
#          '앱에이': 1,
#          '애비': 1,
#          '애버게일': 1,
#          '어케이셔': 1,
#          '애덜린': 1,
#          '애디': 1,
#          '애덜레이드': 1,
#          '어도': 1,
#          '에이드리언': 1,
#          '애거써': 1,
#          '애기': 1,
#          '애그니스': 1,
#          '에이더': 2,
#          '에일린': 1,
#          '앨러미더': 1,
#          '앨버터': 1,
#          '앨바이너': 1,
#          '앨릭스': 1,
#          '앨리그잰드러': 1,
#          '얼렉시어': 1,
#          '앨리스': 1,
#          '얼라인': 1,
#          '앨리선': 1,
#          '얼라이': 1,
#          '앨머': 1,
#          '앨씨어': 1,
#          '어맨더': 1,
#          '앰버': 1,
#          '앰브로저': 1,
#          '어멜리어': 1,
#          '아미': 2,
#          '애머티': 1,
#          '에이미': 1,
#          '에이너': 1,
#          '애너스테이저': 1,
#          '앤드라머키': 1,
#          '앤드라미더': 1,
#          '에인절': 1,
#          '앤절러': 1,
#          '앤젤리커': 1,
#          '앤절리너': 1,
#          '어니터': 1,
#          '아너': 2,
#          '애너벨': 1,
#          '앤': 1,
#          '앤씨어': 1,
#          '앤트워넷': 1,
#          '앤토니어': 1,
#          '애프러다이티': 1,
#          '에이프럴': 1,
#          '에이러': 1,
#          '아든': 1,
#          '애리애드니': 1,
#          '에어리얼': 1,
#          '에이저': 1,
#          '애털랜터': 1,
#          '어씨너': 1,
#          '어씨니': 1,
#          '애틀랜터': 1,
#          '오브리': 1,
#          '오드리': 1,
#          '오거스터': 1,
#          '오거스틴': 1,
#          '오러': 2,
#          '오릴리어': 1,
#          '오로러': 1,
#          '오스턴': 2,
#          '어바': 1,
#          '에이비스': 1,
#          '밥': 2,
#          '바브': 1,
#          '바버러': 1,
#          '바벳': 1,
#          '바리': 2,
#          '배리': 2,
#          '배쓰쉬버': 1,
#          '비어트리스': 1,
#          '보': 1,
#          '베키': 1,
#          '비': 1,
#          '벨': 3,
#          '벌린더': 1,
#          '벨러': 1,
#          '베니': 3,
#          '버레이': 1,
#          '버너뎃': 1,
#          '버너딘': 1,
#          '베리': 1,
#          '버트': 1,
#          '버써': 1,
#          '버티': 2,
#          '베럴': 1,
#          '베시': 1,
#          '베이쓰': 1,
#          '베써니': 1,
#          '베치': 1,
#          '베터': 1,
#          '베티': 1,
#          '뷸러': 1,
#          '베비': 1,
#          '비디': 1,
#          '빌': 1,
#          '빌리': 2,
#          '버드': 2,
#          '버디': 2,
#          '블레이크': 1,
#          '블랜치': 2,
#          '블리스': 1,
#          '블라이드': 1,
#          '블란디': 1,
#          '바비': 2,
#          '바니': 2,
#          '브랜디': 1,
#          '브리': 1,
#          '브렌': 1,
#          '브렌더': 1,
#          '브라이드': 1,
#          '브리짓': 1,
#          '브라이어': 1,
#          '브리지드': 1,
#          '브라이니': 1,
#          '브릿': 2,
#          '브리터니': 1,
#          '브룩': 2,
#          '버피': 1,
#          '버니': 1,
#          '캘러': 1,
#          '컬립소': 1,
#          '캠': 1,
#          '캐멀': 1,
#          '커밀리어': 1,
#          '캐미오': 1,
#          '커밀러': 1,
#          '캐너더': 1,
#          '캔디더': 1,
#          '캔디': 2,
#          '커프리스': 1,
#          '케어리어': 1,
#          '커라이너': 1,
#          '칼린': 4,
#          '칼라일': 2,
#          '칼라터': 1,
#          '카멀': 1,
#          '카먼': 1,
#          '카민': 1,
#          '캐럴': 2,
#          '캐럴라이너': 1,
#          '캐럴라인': 1,
#          '캐리': 2,
#          '캐스': 1,
#          '커샌드러': 1,
#          '캐시': 1,
#          '캣': 1,
#          '케이트': 2,
#          '캐써라이너': 2,
#          '캐써린': 1,
#          '캐씨': 2,
#          '시설': 1,
#          '시실': 1,
#          '시실리어': 1,
#          '세설리': 1,
#          '실': 1,
#          '설레스터': 1,
#          '설레스트': 1,
#          '셀러스타인': 1,
#          '실리어': 1,
#          '채드': 1,
#          '채러티': 1,
#          '샬럿': 1,
#          '채스터티': 1,
#          '첼시': 1,
#          '쉐어': 1,
#          '체리쉬': 1,
#          '체리': 1,
#          '클로이': 1,
#          '크리스': 2,
#          '크리시': 1,
#          '크리슨': 1,
#          '크리스천': 1,
#          '크리스티애너': 1,
#          '크리스티': 2,
#          '크리스티너': 1,
#          '크리스틴': 1,
#          '크라이슬러': 1,
#          '시설리': 1,
#          '신더렐러': 1,
#          '시너먼': 1,
#          '시시': 2,
#          '클레어': 3,
#          '클레어러': 1,
#          '클러리서': 1,
#          '클레어리': 1,
#          '클로드': 1,
#          '클로디어': 1,
#          '클렘': 1,
#          '클레먼틴': 1,
#          '클리오': 2,
#          '클리어패트러': 1,
#          '코디': 1,
#          '칼리': 2,
#          '칸': 1,
#          '칸코디어': 1,
#          '카니': 1,
#          '칸스턴스': 1,
#          '칸스턴시': 1,
#          '컨스탠쉬어': 1,
#          '칸스턴틴': 1,
#          '쿠키': 1,
#          '코러': 2,
#          '코럴': 1,
#          '코딜리어': 1,
#          '코린': 1,
#          '코닐리어': 1,
#          '코니': 1,
#          '코리': 1,
#          '크리스터': 1,
#          '크리스틀': 1,
#          '신씨어': 1,
#          '데이셔': 1,
#          '대피': 1,
#          '댈리어': 1,
#          '데이지': 1,
#          '데일': 1,
#          '댈러스': 1,
#          '더마러': 1,
#          '대니얼': 1,
#          '대니': 1,
#          '대프니': 1,
#          '다브': 1,
#          '다비': 1,
#          '다리': 1,
#          '돈': 1,
#          '뎁': 1,
#          '데비': 1,
#          '데버러': 1,
#          '디': 1,
#          '디어드리': 1,
#          '델': 2,
#          '딜리어': 1,
#          '딜라일러': 1,
#          '델러': 1,
#          '델리': 1,
#          '디미터': 1,
#          '더니스': 1,
#          '디나이': 1,
#          '데니스': 3,
#          '데즈더모너': 1,
#          '데이버': 1,
#          '데이비': 2,
#          '데번': 1,
#          '듀': 1,
#          '다이어먼드': 1,
#          '다이언': 1,
#          '다이애너': 1,
#          '디아도': 1,
#          '다이너': 1,
#          '다이오니': 1,
#          '딕시': 1,
#          '도': 1,
#          '달': 1,
#          '달리': 1,
#          '덜로리스': 1,
#          '다머니커': 1,
#          '다머닉': 3,
#          '도니어': 1,
#          '도너': 1,
#          '다니': 1,
#          '도러': 1,
#          '도커스': 1,
#          '도리언': 1,
#          '도리스': 1,
#          '도리': 1,
#          '닷': 1,
#          '다티': 1,
#          '더브': 1,
#          '드루': 1,
#          '덜스': 1,
#          '덜시애너': 1,
#          '덜시': 1,
#          '덜시니어': 1,
#          '더스티': 1,
#          '이스터': 1,
#          '에버니': 1,
#          '에디': 2,
#          '이든': 1,
#          '이디쓰': 1,
#          '에드너': 1,
#          '에드위너': 1,
#          '에피': 1,
#          '아일린': 1,
#          '일레인': 1,
#          '엘버터': 1,
#          '엘러너': 1,
#          '일렉트러': 1,
#          '얼레이너': 1,
#          '엘리너': 1,
#          '일리저버쓰': 2,
#          '일리스': 1,
#          '일라이셔': 1,
#          '일라이저': 2,
#          '엘러': 1,
#          '엘런': 1,
#          '엘러위즈': 1,
#          '엘서': 1,
#          '엘스': 1,
#          '엘시': 1,
#          '엘서노': 1,
#          '엘바이어러': 1,
#          '에일리제이': 1,
#          '이밀리어': 1,
#          '에머': 1,
#          '에멀린': 1,
#          '에미': 1,
#          '이니드': 1,
#          '어더': 1,
#          '에리커': 1,
#          '에린': 1,
#          '어니스틴': 1,
#          '에시': 1,
#          '에스터': 2,
#          '에썰': 2,
#          '에터': 1,
#          '유지니어': 1,
#          '유피미어': 1,
#          '이버': 1,
#          '이밴절린': 1,
#          '이브': 1,
#          '에벌라이너': 1,
#          '에벌라인': 1,
#          '에벌린': 1,
#          '페이쓰': 1,
#          '팬': 1,
#          '팬시': 1,
#          '패니': 1,
#          '패런드': 2,
#          '패티머': 1,
#          '폰': 2,
#          '페이': 2,
#          '피도러': 1,
#          '펄리쉬어': 1,
#          '필리서티': 1,
#          '펀': 1,
#          '퍼낸더': 1,
#          '피어너': 1,
#          '피딜리어': 1,
#          '피델러티': 1,
#          '플러렛': 1,
#          '플로': 1,
#          '플로러': 1,
#          '플로런스': 1,
#          '플로리더': 1,
#          '플로리': 1,
#          '플로시': 2,
#          '플라워': 1,
#          '포튜너': 1,
#          '포천': 1,
#          '프랜스': 1,
#          '프랜시스': 2,
#          '프랜체스커': 1,
#          '프랭크': 1,
#          '프레드': 1,
#          '프리더': 1,
#          '게이브리얼': 1,
#          '게이브리엘': 1,
#          '게이비': 1,
#          '게일': 4,
#          '갈런드': 1,
#          '가닛': 1,
#          '게이츠': 1,
#          '게이': 1,
#          '젠': 1,
#          '진': 2,
#          '저니버': 1,
#          '제너비브': 1,
#          '조지': 2,
#          '조젯': 1,
#          '조저': 1,
#          '조지애너': 1,
#          '조지너': 1,
#          '게러': 1,
#          '제럴딘': 1,
#          '게리': 1,
#          '거티': 1,
#          '거트룻': 1,
#          '길': 1,
#          '질리언': 1,
#          '길리': 2,
#          '진저': 1,
#          '집시': 2,
#          '글래드': 1,
#          '글래디스': 1,
#          '글렌': 1,
#          '글로리어': 1,
#          '글로리': 1,
#          '거다이버': 1,
#          '골디': 1,
#          '그레이스': 1,
#          '그레이': 1,
#          '그레천': 1,
#          '그리젤더': 1,
#          '그웨너비어': 1,
#          '귀너비어': 1,
#          '거스': 1,
#          '거시': 2,
#          '거스티': 1,
#          '귄': 1,
#          '헤일리': 1,
#          '핼리': 1,
#          '해너': 1,
#          '해너벌': 1,
#          '해피': 1,
#          '할리': 2,
#          '하머니': 1,
#          '해리어트': 1,
#          '해티': 1,
#          '헤이절': 1,
#          '히쓰': 1,
#          '헤더': 2,
#          '헬런': 1,
#          '헬러너': 1,
#          '헬린': 1,
#          '헨리에터': 1,
#          '허써': 1,
#          '헤스터': 1,
#          '헤스티어': 1,
#          '헤티': 1,
#          '힐러리': 2,
#          '힐더': 1,
#          '허니': 1,
#          '홉': 1,
#          '호텐스': 1,
#          '하이어신쓰': 1,
#          '아이크': 1,
#          '아이키': 1,
#          '이네즈': 1,
#          '인지': 1,
#          '잉그러드': 1,
#          '아이오너': 1,
#          '아이어러': 1,
#          '아이린': 1,
#          '아이어리스': 1,
#          '어머': 1,
#          '이저벨': 1,
#          '이저벨러': 1,
#          '이저도러': 1,
#          '아이시스': 1,
#          '아이버리': 1,
#          '아이비': 1,
#          '재키': 2,
#          '재클린': 1,
#          '제이드': 1,
#          '잰': 1,
#          '제인': 1,
#          '재닛': 1,
#          '야니나': 1,
#          '재즈민': 1,
#          '저마이머': 1,
#          '제미': 1,
#          '예너': 1,
#          '제니': 1,
#          '제리': 1,
#          '제스': 1,
#          '제서민': 2,
#          '제시': 2,
#          '제시커': 1,
#          '주얼': 1,
#          '질': 1,
#          '존': 1,
#          '조애너스': 1,
#          '자설린': 1,
#          '조디': 1,
#          '조이': 2,
#          '조던': 1,
#          '조저핀': 1,
#          '조시': 1,
#          '조이스': 1,
#          '조이어스': 1,
#          '줏': 1,
#          '주디쓰': 1,
#          '주디': 1,
#          '줄리어': 1,
#          '줄리애너': 1,
#          '줄리엔': 1,
#          '줄리어트': 1,
#          '준': 1,
#          '저스턴': 1,
#          '저스티너': 1,
#          '캘리': 1,
#          '캐런': 1,
#          '캇': 1,
#          '캐쓸린': 1,
#          '캐트린': 1,
#          '케이': 1,
#          '켈리': 1,
#          '케리': 1,
#          '킴벌리': 1,
#          '킵': 1,
#          '킷': 1,
#          '키티': 1,
#          '카일': 1,
#          '레이시': 1,
#          '램': 2,
#          '레인': 1,
#          '레어리': 1,
#          '래런': 1,
#          '라크': 1,
#          '라브러': 1,
#          '로럴': 1,
#          '로레터': 2,
#          '로리': 4,
#          '러비니어': 1,
#          '리': 4,
#          '리어': 2,
#          '리더': 1,
#          '릴러': 1,
#          '리너': 2,
#          '리어노러': 1,
#          '레슬리': 2,
#          '리티셔': 1,
#          '레티': 1,
#          '리아너': 1,
#          '립': 1,
#          '리비': 2,
#          '릴리언': 1,
#          '릴리쓰': 1,
#          '릴리': 1,
#          '린': 2,
#          '린드': 1,
#          '린더': 1,
#          '린지': 2,
#          '린디': 1,
#          '리닛': 1,
#          '리어러': 1,
#          '리서': 3,
#          '리즈': 1,
#          '리지': 1,
#          '로이스': 2,
#          '랄리': 1,
#          '로럴라이': 1,
#          '로런': 1,
#          '로너': 1,
#          '러레인': 1,
#          '라터': 1,
#          '러브': 1,
#          '류스': 1,
#          '루쉬어': 1,
#          '루사이너': 1,
#          '러키': 1,
#          '류크리셔': 1,
#          '루시': 1,
#          '룰루': 1,
#          '루너': 1,
#          '러스트': 1,
#          '리디어': 1,
#          '맵': 1,
#          '메이블': 1,
#          '매덜린': 1,
#          '매지': 1,
#          '머다너': 1,
#          '매그': 1,
#          '매그덜런': 1,
#          '매그덜레이너': 1,
#          '메이~어': 1,
#          '메이지': 1,
#          '맬러리': 1,
#          '메이미': 1,
#          '머라': 1,
#          '마셀러': 1,
#          '마거릿': 2,
#          '마거리터': 1,
#          '마고': 1,
#          '마지': 1,
#          '마리어': 1,
#          '메어리언': 2,
#          '메어리앤': 1,
#          '머리': 2,
#          '매리골드': 1,
#          '매린': 1,
#          '머리너': 1,
#          '머리처': 1,
#          '말리너': 1,
#          '만': 1,
#          '매리': 1,
#          '마써': 1,
#          '메어리': 1,
#          '머틸더': 1,
#          '모드': 1,
#          '메이비스': 1,
#          '맥시': 1,
#          '맥신': 1,
#          '메이': 1,
#          '마야': 1,
#          '미드': 2,
#          '메그': 1,
#          '멜': 1,
#          '멜버': 1,
#          '멀리서': 1,
#          '멜러디': 1,
#          '메어시': 1,
#          '머시': 1,
#          '메리디쓰': 1,
#          '멀': 1,
#          '메럴리': 1,
#          '메리': 1,
#          '머지': 1,
#          '메터': 1,
#          '미지': 1,
#          '미냔': 1,
#          '밀드러드': 1,
#          '민': 1,
#          '마이너': 2,
#          '미너버': 1,
#          '머넷': 1,
#          '미너': 1,
#          '미니': 1,
#          '미랜더': 1,
#          '미시': 1,
#          '엘 미스티': 1,
#          '미스티': 1,
#          '마더스티': 1,
#          '모이러': 1,
#          '말': 1,
#          '말리': 1,
#          '마미': 1,
#          '모너': 1,
#          '모러': 1,
#          '머린': 1,
#          '모건': 2,
#          '모젤': 1,
#          '모이어': 1,
#          '머핀': 1,
#          '머틀': 1,
#          '나더': 1,
#          '낸': 1,
#          '나너': 1,
#          '낸스': 1,
#          '낸시': 1,
#          '내넷': 1,
#          '내니': 2,
#          '네이오미': 1,
#          '냇': 1,
#          '내티': 1,
#          '넬': 1,
#          '넬리': 1,
#          '네시': 1,
#          '네티': 2,
#          '네틀': 1,
#          '나이키': 1,
#          '닐': 3,
#          '니너': 1,
#          '니농': 1,
#          '니터': 1,
#          '닉시': 1,
#          '노엘': 1,
#          '노러': 1,
#          '노머': 1,
#          '노버': 1,
#          '악테이비어': 1,
#          '알리브': 1,
#          '올리비어': 1,
#          '얼림피어': 1,
#          '오펄': 1,
#          '오펄린': 1,
#          '오필리어': 1,
#          '오렐': 1,
#          '오리에이너': 1,
#          '올리': 1,
#          '페이지': 1,
#          '팸': 1,
#          '팬도러': 1,
#          '팬지': 1,
#          '팻': 1,
#          '페이션스': 1,
#          '패치': 1,
#          '패티': 2,
#          '폴리': 1,
#          '폴라인': 1,
#          '펄': 1,
#          '페그': 1,
#          '펜': 2,
#          '퍼넬러피': 1,
#          '페니': 2,
#          '피어리': 1,
#          '페리': 1,
#          '퍼시스': 1,
#          '펫': 1,
#          '피트러': 1,
#          '피튜니어': 1,
#          '피드러': 1,
#          '피비': 2,
#          '필러핀': 1,
#          '필리스': 1,
#          '파이얼': 1,
#          '피어': 1,
#          '파이퍼': 1,
#          '팔리': 1,
#          '푸': 1,
#          '파피': 1,
#          '포셔': 1,
#          '프리실러': 1,
#          '프루든스': 1,
#          '프루넬러': 1,
#          '퀜튼': 1,
#          '퀸': 1,
#          '러쉘': 1,
#          '아레이에프': 1,
#          '레이너': 1,
#          '랜디': 1,
#          '라니': 2,
#          '레이븐': 1,
#          '레이': 2,
#          '리버': 1,
#          '리베커': 2,
#          '레지': 1,
#          '리자이너': 1,
#          '로더': 1,
#          '리터': 1,
#          '라빈': 2,
#          '러버터': 1,
#          '로비니어': 1,
#          '러몰러': 1,
#          '로저': 1,
#          '로제일리어': 1,
#          '로즈': 1,
#          '로젤러': 1,
#          '로젤': 1,
#          '로즈메어리': 1,
#          '로제터': 1,
#          '로젯': 1,
#          '로지': 2,
#          '로': 2,
#          '로위너': 1,
#          '락새너': 1,
#          '루비': 1,
#          '루쓰': 1,
#          '사버': 1,
#          '서바이너': 1,
#          '세이바인': 1,
#          '사브러': 1,
#          '서브리너': 1,
#          '세이디': 1,
#          '샐': 1,
#          '샐리': 1,
#          '설로미': 1,
#          '서맨써': 1,
#          '새머러': 1,
#          '서메어리어': 1,
#          '새미': 1,
#          '샌드러': 1,
#          '샌디': 1,
#          '서파이어러': 1,
#          '새파이어': 1,
#          '세어러': 1,
#          '사리': 2,
#          '스칼릿': 1,
#          '숀': 1,
#          '실리니': 1,
#          '서리너': 1,
#          '서린': 1,
#          '셴디': 1,
#          '쉐넌': 1,
#          '샤리': 1,
#          '셔리어': 1,
#          '쇼니': 1,
#          '쉐이': 1,
#          '쉬버': 1,
#          '쉴러': 1,
#          '쉘': 1,
#          '쉘리': 2,
#          '셰리': 1,
#          '셜': 1,
#          '셜리': 1,
#          '십': 1,
#          '시빌': 1,
#          '사일': 1,
#          '실버': 1,
#          '수': 2,
#          '소피어': 2,
#          '서니': 2,
#          '소피': 1,
#          '스타': 1,
#          '스텔러': 1,
#          '스토리': 1,
#          '스톰': 1,
#          '스토미': 1,
#          '수재너': 1,
#          '시벌': 1,
#          '시드니': 2,
#          '태비': 1,
#          '태피': 1,
#          '탤리': 1,
#          '태미': 1,
#          '타너': 1,
#          '탠지': 1,
#          '태러': 1,
#          '테이트': 2,
#          '테이텀': 1,
#          '테드': 1,
#          '테디': 1,
#          '테러지너': 1,
#          '테러': 1,
#          '테리': 1,
#          '씨어': 1,
#          '쎌머': 1,
#          '씨어도러': 1,
#          '터리서': 1,
#          '티프': 1,
#          '티퍼니': 1,
#          '틸더': 1,
#          '틸리': 1,
#          '타인': 2,
#          '터비': 1,
#          '토비': 2,
#          '타미': 1,
#          '토니': 2,
#          '투치': 1,
#          '토라이': 1,
#          '토리': 1,
#          '트레이스': 1,
#          '트레이시': 1,
#          '튜즈데이': 1,
#          '얼러커': 1,
#          '우너': 1,
#          '어서': 1,
#          '어설러': 1,
#          '어설런': 1,
#          '베일': 2,
#          '벌렌쉬어': 1,
#          '밸런타인': 1,
#          '벌레어러': 1,
#          '벌리어리어': 1,
#          '발레리': 1,
#          '밴': 1,
#          '밴더': 1,
#          '버네서': 1,
#          '베이더': 1,
#          '벨빗': 1,
#          '비너': 1,
#          '비너스': 1,
#          '베러': 1,
#          '버라니커': 1,
#          '비키': 1,
#          '빅토리어': 1,
#          '비더': 1,
#          '비나': 1,
#          '비올러': 1,
#          '바이얼릿': 1,
#          '버지니어': 1,
#          '바이터': 1,
#          '비토리어': 1,
#          '비버': 1,
#          '비비언': 2,
#          '발리스': 1,
#          '웨일리': 2,
#          '윗니': 1,
#          '윌리': 2,
#          '윌로': 1,
#          '윈디': 1,
#          '렌': 1,
#          '윈': 3,
#          '지니어': 1,
#          '이올랜더': 1,
#          '이반': 1,
#          '지아': 1,
#          '졸러': 1,
#          '에어런': 1,
#          '애벗': 1,
#          '에입': 1,
#          '에이벌': 1,
#          '애벌라드': 1,
#          '에이브러햄': 1,
#          '에이브럼': 1,
#          '애덤': 1,
#          '애덤즈': 1,
#          '애달프': 1,
#          '어달퍼스': 1,
#          '애거멤난': 1,
#          '앨런': 2,
#          '앨버트': 1,
#          '앨리그잰더': 1,
#          '앨프레드': 1,
#          '앨러': 1,
#          '앨리': 1,
#          '앰브로즈': 1,
#          '에이머스': 1,
#          '앤드루': 1,
#          '앤드라스': 1,
#          '앵거스': 1,
#          '앤세름': 1,
#          '앤써니': 1,
#          '앤토니오': 1,
#          '앤토니어스': 1,
#          '앤터니': 1,
#          '어팔로': 1,
#          '에이램': 1,
#          '아처볼드': 1,
#          '아치': 2,
#          '아칸': 1,
#          '애리스타틀': 1,
#          '암스트롱': 1,
#          '안': 1,
#          '아널드': 1,
#          '아트': 1,
#          '아써': 1,
#          '애쉬': 1,
#          '애쉬턴': 1,
#          '옵': 1,
#          '오거스트': 1,
#          '오거스터스': 1,
#          '아베이': 1,
#          '에이버리': 1,
#          '에일머': 1,
#          '베일리': 2,
#          '베어드': 1,
#          '볼드윈': 1,
#          '바드': 1,
#          '반': 2,
#          '바너버스': 1,
#          '바너드': 1,
#          '배런': 1,
#          '배릿': 1,
#          '바트': 1,
#          '바쓰': 1,
#          '바쌀러뮤': 1,
#          '바틀럿': 1,
#          '바튼': 1,
#          '배절': 1,
#          '베이': 1,
#          '베이어드': 1,
#          '베어': 1,
#          '벡': 1,
#          '벤': 1,
#          '베니딕트': 1,
#          '벤저먼': 1,
#          '벤지': 1,
#          '베닛': 2,
#          '벤틀리': 1,
#          '베이어울프': 1,
#          '버크': 2,
#          '버클리': 1,
#          '버너드': 1,
#          '버트럼': 1,
#          '버트런드': 1,
#          '버럿': 1,
#          '비프': 1,
#          '빙': 1,
#          '비셥': 1,
#          '블레어': 1,
#          '바가트': 1,
#          '바너페이스': 1,
#          '보이드': 1,
#          '브래드': 1,
#          '브래드포드': 1,
#          '브래들리': 1,
#          '브랜트': 1,
#          '브렌트': 1,
#          '브루어': 1,
#          '브루스터': 1,
#          '브라이언': 2,
#          '브리그즈': 1,
#          '브락': 1,
#          '브로디': 1,
#          '브루스': 1,
#          '브루노': 1,
#          '벅': 1,
#          '버지스': 1,
#          '벌': 1,
#          '버튼': 1,
#          '버스터': 1,
#          '부치': 1,
#          '벗러': 1,
#          '바이어런': 1,
#          '시저': 1,
#          '케인': 1,
#          '콜드웰': 1,
#          '캘빈': 1,
#          '칼': 1,
#          '칼러스': 1,
#          '칼턴': 1,
#          '카슨': 1,
#          '카터': 1,
#          '케이스': 1,
#          '캐스퍼': 1,
#          '채드위크': 1,
#          '챈스': 1,
#          '챈들러': 1,
#          '채리어트': 1,
#          '찰즈': 1,
#          '찰리': 2,
#          '체이스': 1,
#          '체스터': 1,
#          '쉐벌리어': 1,
#          '체비': 1,
#          '칩': 1,
#          '크라이스트': 1,
#          '크리스토프': 1,
#          '크리스터퍼': 1,
#          '척': 1,
#          '처칠': 1,
#          ...})

# %%
from collections import Counter
