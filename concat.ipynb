# %%
import pickle
with open("dic1_1.pkl","rb") as f:
    dic1 = pickle.load(f)
    
import pickle
with open("dic1_2.pkl","rb") as f:
    dic2 = pickle.load(f)
    
import pickle
with open("dic1_3.pkl","rb") as f:
    dic3 = pickle.load(f)
    
import pickle
with open("dic1_4.pkl","rb") as f:
    dic4 = pickle.load(f)
    
import pickle
with open("dic1_5.pkl","rb") as f:
    dic5 = pickle.load(f)
    
import pickle
with open("dic1_6.pkl","rb") as f:
    dic6 = pickle.load(f)

# %%
dic7 = dict()
dic7.update(dic1)
dic7.update(dic2)
dic7.update(dic3)
dic7.update(dic4)
dic7.update(dic5)
dic7.update(dic6)

# %%
import regex
regex.match('^[a-z|A-Z]', "가")  == None
# Out:
# True

# %%
count = 0
for i in dic7:
    if dic7[i] == "":
        count += 1
print(count)
# Out:
# 168799

# %%
from text_normalize_v1 import normalize
from tqdm import tqdm

# %%
normalize("acetylene")
# Out:
# 'acetylene'

# %%
import pickle
with open("/home/jo/IPTV/text_normalize/dic3.pkl","rb") as f:
    dic9 = pickle.load(f)

# %%
pwd
# Out:
# '/home/jo/IPTV/text_normalize'

# %%
import pickle
with open("/home/jo/IPTV/text_normalize/Korean-Transliteration/engkor_transliterator/dic2_1.pkl","rb") as f:
    dic8 = pickle.load(f)

# %%
dic9
# Out:
# {'Abagael': '',
#  'Abagail': '',
#  'Abbe': '앱에이',
#  'Abbey': '애비',
#  'Abbi': '',
#  'Abbie': '',
#  'Abby': '',
#  'Abigael': '',
#  'Abigail': '애버게일',
#  'Abigale': '',
#  'Abra': '',
#  'Acacia': '어케이셔',
#  'Ada': '',
#  'Adah': '',
#  'Adaline': '애덜린',
#  'Adara': '',
#  'Addie': '애디',
#  'Addis': '',
#  'Adel': '',
#  'Adela': '',
#  'Adelaide': '애덜레이드',
#  'Adele': '',
#  'Adelice': '',
#  'Adelina': '',
#  'Adelind': '',
#  'Adeline': '',
#  'Adella': '',
#  'Adelle': '',
#  'Adena': '',
#  'Adey': '',
#  'Adi': '',
#  'Adiana': '',
#  'Adina': '',
#  'Adora': '',
#  'Adore': '어도',
#  'Adoree': '',
#  'Adorne': '',
#  'Adrea': '',
#  'Adria': '',
#  'Adriaens': '',
#  'Adrian': '에이드리언',
#  'Adriana': '',
#  'Adriane': '',
#  'Adrianna': '',
#  'Adrianne': '',
#  'Adrien': '',
#  'Adriena': '',
#  'Adrienne': '',
#  'Aeriel': '',
#  'Aeriela': '',
#  'Aeriell': '',
#  'Ag': '',
#  'Agace': '',
#  'Agata': '',
#  'Agatha': '애거써',
#  'Agathe': '',
#  'Aggi': '',
# ...

# %%
dic8
# Out:
# {'A': '이이',
#  'a': '이이',
#  'aa': '에에에',
#  'aal': '엘',
#  'aam': '에이에에엠',
#  'Aani': '아니',
#  'Aaronical': '애러니컬',
#  'Aaronite': '아로나이트',
#  'Aaronitic': '아로니틱',
#  'Aaru': '아올',
#  'Ab': '에비비',
#  'Ababdeh': '아바다',
#  'Ababua': '아바부아',
#  'abacate': '아바케이트',
#  'abacay': '아바케이',
#  'abacinate': '아바시네이트',
#  'abacination': '아바시네이션',
#  'abaciscus': '아바시스커스',
#  'abactinally': '아박티날리',
#  'abaction': '애백션',
#  'abactor': '아박터',
#  'Abadite': '애바다이트',
#  'abaff': '아배프',
#  'abaisance': '애버이전스',
#  'abaiser': '아바이서',
#  'abaissed': '아바이스',
#  'abalienation': '애벌리에네션',
#  'Abama': '애바마',
#  'abandonable': '어밴더나블',
#  'abandonedly': '애반던델리',
#  'Abanic': '아바닉',
#  'Abantes': '아반테스',
#  'abaptiston': '아밥티스턴',
#  'Abarambo': '아바람보',
#  'Abaris': '아바리스',
#  'abarthrosis': '아바르로시스',
#  'abarticular': '아바티쿨라',
#  'abarticulation': '아바리큘레이션',
#  'abas': '애버스',
#  'abased': '아바세드',
#  'abasedly': '아바세들리',
#  'abasedness': '아바세드네스',
#  'Abasgi': '아바시',
#  'abashed': '아바세드',
# ...

# %%
for i in dic8:
    dic7[i] = dic8[i]

# %%
len()

# %%
len(dic7)
# Out:
# 235892
