# %% [markdown]
# 코퍼스(corpus)(말뭉치)는 정형이나 비정형인 단어나 표현의 묶음이다. 모든 NLTK 코퍼스는 nltk.corpus 모듈에 저장되어 있다. 예를 들면 다음과 같다.
#
#
#
# ◼︎ gutenberg : <모비딕(Moby Dick)>이나 <성경> 등 구텐베르크 프로젝트(Gutenberg Project)에서 제공하는 영문 텍스트 18개
#
# ◼︎ names : 8000개의 남성과 여성의 이름 리스트
#
# ◼︎ words : 가장 빈번하게 사용하는 영어 단어 23만 5000개
#
# ◼︎ stopwords : 14개의 언어로 된 가장 많이 사용하는 불용어(stop word) 리스트. 영어로 된 리스트는 stop words.words("english")에 저장되어 있다. 불용어는 대부분의 분석에서 보통 삭제하는데, 텍스트 이해에 별로 기여하는 바가 없기 때문이다.
#
# ◼︎ cmudict : 카네기멜론대학교에서 만든 발음 사전으로 13만 4000개 입력 데이터가 있다. cmudict.entries()의 각 입력 데이터는 단어와 그 음절(syllables) 리스트의 튜플이다. 단어가 같더라도 다르게 발음할 수 있다. 이 코퍼스를 사용하면 발음이 같은 동음이의어(homophones)를 찾아볼 수 있다

# %% [markdown]
# from nltk.corpus import stopwords
# print(len(stopwords.words()))

# %%
from nltk.corpus import words
print(len(words.words()))
from nltk.corpus import names
print(len(names.words()))
# Out:
# 236736
# 7944

# %%
import requests 
from bs4 import BeautifulSoup 
dic8 = dict()
for search_query in tqdm(words.words()[40000:80000]):
    url = (f'http://aha-dic.com/View.asp?word={search_query}')
    res = requests.get(url) 
    soup = BeautifulSoup(res.text, "lxml")
    
    try:
        dic8[search_query] = soup.find_all("span", {"class": "phoneticKor"})[0].text.replace("[","").replace("]","")
    except:
        dic8[search_query] = ""
# Out:
# 100%|██████████| 40000/40000 [55:51<00:00, 11.94it/s]

# %% [markdown]
# import pickle
# with open("dic1_2.pkl","wb") as f:
#     pickle.dump(dic8,f)

# %%
dic8
# Out:
# {'commenter': '카멘터',
#  'commerce': '카머스',
#  'commerceless': '',
#  'commercer': '',
#  'commerciable': '',
#  'commercial': '커머셜',
#  'commercialism': '커머셜리즘',
#  'commercialist': '',
#  'commercialistic': '',
#  'commerciality': '',
#  'commercialization': '커머셜러제이션',
#  'commercialize': '커머셜라이즈',
#  'commercially': '커머셜리',
#  'commercium': '',
#  'commerge': '',
#  'commie': '카미',
#  'comminate': '카머네이트',
#  'commination': '카머네이션',
#  'comminative': '',
#  'comminator': '',
#  'comminatory': '커미너토리',
#  'commingle': '커밍글',
#  'comminglement': '',
#  'commingler': '커밍글러',
#  'comminister': '',
#  'comminuate': '',
#  'comminute': '카머뉴트',
#  'comminution': '카머뉴션',
#  'comminutor': '',
#  'Commiphora': '',
#  'commiserable': '커미저러블',
#  'commiserate': '커미저레이트',
#  'commiseratingly': '',
#  'commiseration': '커미저레이션',
#  'commiserative': '커미저레이티브',
#  'commiseratively': '',
#  'commiserator': '커미제레이터',
#  'commissar': '카머사',
#  'commissarial': '카머세어리얼',
#  'commissariat': '카미세어리어트',
#  'commissary': '카머세리',
#  'commissaryship': '',
#  'commission': '커미션',
#  'commissionaire': '커미셔네어',
#  'commissional': '',
#  'commissionate': '',
#  'commissioner': '커미셔너',
#  'commissionership': '',
#  'commissionship': '',
#  'commissive': '',
#  'commissively': '',
#  'commissural': '커미셔럴',
#  'commissure': '카미슈어',
#  'commissurotomy': '',
#  'commit': '커밋',
#  'commitment': '커밋먼트',
#  'committable': '커미터블',
#  'committal': '커미틀',
#  'committee': '커미티',
#  'committeeism': '',
#  'committeeman': '',
#  'committeeship': '',
#  'committeewoman': '커미티우먼',
#  'committent': '',
#  'committer': '',
#  'committible': '',
#  'committor': '',
#  'commix': '커믹스',
#  'commixt': '',
#  'commixtion': '',
#  'commixture': '커믹스처',
#  'commodatary': '',
#  'commodate': '',
#  'commodation': '',
#  'commodatum': '',
#  'commode': '커모드',
#  'commodious': '커모디어스',
#  'commodiously': '커모디어슬리',
#  'commodiousness': '커모디어스니스',
#  'commoditable': '',
#  'commodity': '커마더티',
#  'commodore': '카머도',
#  'common': '카먼',
#  'commonable': '카머너블',
#  'commonage': '카머니지',
#  'commonality': '카머낼러티',
#  'commonalty': '카머널티',
#  'commoner': '카머너',
#  'commonership': '',
#  'commoney': '',
#  'commonish': '',
#  'commonition': '',
#  'commonize': '',
#  'commonly': '카먼리',
#  'commonness': '카먼니스',
#  'commonplace': '',
#  'commonplaceism': '',
#  'commonplacely': '',
#  'commonplaceness': '카먼플레이스니스',
#  'commonplacer': '',
#  'commons': '카먼즈',
#  'commonsensible': '',
#  'commonsensibly': '',
#  'commonsensical': '카먼센서클',
#  'commonsensically': '',
#  'commonty': '',
#  'commonweal': '카먼윌',
#  'commonwealth': '카먼우엘쓰',
#  'commonwealthism': '',
#  'commorancy': '카머런시',
#  'commorant': '카머런트',
#  'commorient': '',
#  'commorth': '',
#  'commot': '',
#  'commotion': '커모션',
#  'commotional': '',
#  'commotive': '',
#  'commove': '커무브',
#  'communa': '',
#  'communal': '커뮤널',
#  'communalism': '커뮤널리즘',
#  'communalist': '커뮤널리스트',
#  'communalistic': '커뮤널리스틱',
#  'communality': '카뮤낼러티',
#  'communalization': '',
#  'communalize': '커뮤널라이즈',
#  'communalizer': '',
#  'communally': '커뮤널리',
#  'communard': '카뮤나드',
#  'commune': '커뮨',
#  'communer': '',
#  'communicability': '커뮤니커빌러티',
#  'communicable': '커뮤너커블',
#  'communicableness': '',
#  'communicably': '',
#  'communicant': '커뮤너컨트',
#  'communicate': '커뮤너케이트',
#  'communicatee': '커뮤니커티',
#  'communicating': '',
#  'communication': '커뮤너케이션',
#  'communicative': '커뮤너케이티브',
#  'communicatively': '',
#  'communicativeness': '커뮤너케이티브니스',
#  'communicator': '커뮤너케이터',
#  'communicatory': '커뮤너커토리',
#  'communion': '커뮤니언',
#  'communionist': '커뮤니어니스트',
#  'communique': '커뮤니케이',
#  'communism': '카뮤니즘',
#  'communist': '카뮤니스트',
#  'communistery': '',
#  'communistic': '카뮤니스틱',
#  'communistically': '',
#  'communital': '',
#  'communitarian': '커뮤니테어리언',
#  'communitary': '',
#  'communitive': '',
#  'communitorium': '',
#  'community': '커뮤너티',
#  'communization': '카뮤니제이션',
#  'communize': '카뮤나이즈',
#  'commutability': '커뮤터빌러티',
#  'commutable': '커뮤터블',
#  'commutableness': '',
#  'commutant': '',
#  'commutate': '카뮤테이트',
#  'commutation': '카뮤테이션',
#  'commutative': '카뮤테이티브',
#  'commutatively': '',
#  'commutator': '카뮤테이터',
#  'commute': '커뮤트',
#  'commuter': '커뮤터',
#  'commuting': '',
#  'commutual': '커뮤추얼',
#  'commutuality': '',
#  'Comnenian': '',
#  'comoid': '',
#  'comolecule': '',
#  'comortgagee': '',
#  'comose': '코모스',
#  'comourn': '',
#  'comourner': '',
#  'comournful': '',
#  'comous': '',
#  'Comox': '',
#  'compact': '컴팩트',
#  'compacted': '컴팩티드',
#  'compactedly': '컴팩티들리',
#  'compactedness': '컴팩티드니스',
#  'compacter': '',
#  'compactible': '컴팩터블',
#  'compaction': '컴팩션',
#  'compactly': '컴팩틀리',
#  'compactness': '컴팩트니스',
#  'compactor': '컴팩터',
#  'compacture': '',
#  'compages': '컴페이지즈',
#  'compaginate': '컴패저네이트',
#  'compagination': '',
#  'companator': '',
#  'companion': '컴패니언',
#  'companionability': '',
#  'companionable': '컴패니어너블',
#  'companionableness': '',
#  'companionably': '컴패니어너블리',
#  'companionage': '',
#  'companionate': '컴패니어닛',
#  'companionize': '',
#  'companionless': '컴패니언리스',
#  'companionship': '컴패니언쉽',
#  'companionway': '',
#  'company': '컴퍼니',
#  'comparability': '캄퍼러빌러티',
#  'comparable': '캄퍼러블',
#  'comparableness': '',
#  'comparably': '캄퍼러블리',
#  'comparascope': '',
#  'comparate': '',
#  'comparatival': '',
#  'comparative': '컴패러티브',
#  'comparatively': '컴패러티블리',
#  'comparativeness': '',
#  'comparativist': '컴패러티비스트',
#  'comparator': '캄퍼레이터',
#  'compare': '컴페어',
#  'comparer': '',
#  'comparison': '컴패리슨',
#  'comparition': '',
#  'comparograph': '',
#  'compart': '컴파트',
#  'compartition': '',
#  'compartment': '컴파트먼트',
#  'compartmental': '컴파트멘틀',
#  'compartmentalization': '',
#  'compartmentalize': '컴 파트멘털라이즈',
#  'compartmentally': '',
#  'compartmentize': '',
#  'compass': '컴퍼스',
#  'compassable': '컴퍼서블',
#  'compasser': '',
#  'compasses': '',
#  'compassing': '',
#  'compassion': '컴패션',
#  'compassionable': '',
#  'compassionate': '컴패셔넛',
#  'compassionately': '컴패셔넛리',
#  'compassionateness': '컴패셔넛니스',
#  'compassionless': '',
#  'compassive': '',
#  'compassivity': '',
#  'compassless': '',
#  'compaternity': '',
#  'compatibility': '컴패터빌러티',
#  'compatible': '컴패터블',
#  'compatibleness': '컴패터블니스',
#  'compatibly': '컴패터블리',
#  'compatriot': '컴페이트리어트',
#  'compatriotic': '컴페이트리아틱',
#  'compatriotism': '',
#  'compear': '',
#  'compearance': '',
#  'compearant': '',
#  'compeer': '컴피어',
#  'compel': '컴펠',
#  'compellable': '컴펠러블',
#  'compellably': '',
#  'compellation': '캄펄레이션',
#  'compellative': '',
#  'compellent': '',
#  'compeller': '',
#  'compelling': '컴펠링',
#  'compellingly': '',
#  'compend': '캄펜드',
#  'compendency': '',
#  'compendent': '',
#  'compendia': '',
#  'compendiary': '',
#  'compendiate': '',
#  'compendious': '컴펜디어스',
#  'compendiously': '컴펜디어슬리',
#  'compendiousness': '컴펜디어스니스',
#  'compendium': '컴펜디엄',
#  'compenetrate': '',
#  'compenetration': '',
#  'compensable': '컴펜서블',
#  'compensate': '캄펀세이트',
#  'compensating': '',
#  'compensatingly': '',
#  'compensation': '캄펀세이션',
#  'compensational': '',
#  'compensative': '캄펀세이티브',
#  'compensativeness': '',
#  'compensator': '캄펀세이터',
#  'compensatory': '컴펜서토리',
#  'compense': '',
#  'compenser': '',
#  'compesce': '',
#  'compete': '컴핏',
#  'competence': '캄퍼턴스',
#  'competency': '캄피턴시',
#  'competent': '캄퍼턴트',
#  'competently': '캄퍼턴틀리',
#  'competentness': '',
#  'competition': '캄퍼티션',
#  'competitioner': '',
#  'competitive': '컴페터티브',
#  'competitively': '',
#  'competitiveness': '컴페터티브니스',
#  'competitor': '컴페터터',
#  'competitorship': '',
#  'competitory': '컴페티토리',
#  'competitress': '',
#  'competitrix': '',
#  'compilation': '캄펄레이션',
#  'compilator': '',
#  'compilatory': '컴파일러토리',
#  'compile': '컴파일',
#  'compilement': '',
#  'compiler': '컴파일러',
#  'compital': '',
#  'Compitalia': '',
#  'compitum': '',
#  'complacence': '컴플레이슨스',
#  'complacency': '컴플레이슨시',
#  'complacent': '컴플레이슨트',
#  'complacential': '',
#  'complacentially': '',
#  'complacently': '컴플레이슨틀리',
#  'complain': '컴플레인',
#  'complainable': '',
#  'complainant': '컴플레이넌트',
#  'complainer': '컴플레이너',
#  'complainingly': '컴플레이닝리',
#  'complainingness': '',
#  'complaint': '컴플레인트',
#  'complaintive': '',
#  'complaintiveness': '',
#  'complaisance': '컴플레이슨스',
#  'complaisant': '컴플레이슨트',
#  'complaisantly': '',
#  'complaisantness': '',
#  'complanar': '',
#  'complanate': '캄플러네이트',
#  'complanation': '캄플러네이션',
#  'complect': '컴플렉트',
#  'complected': '컴플렉티드',
#  'complement': '캄플러먼트',
#  'complemental': '캄플러멘틀',
#  'complementally': '',
#  'complementalness': '',
#  'complementariness': '',
#  'complementarism': '',
#  'complementary': '캄플러멘터리',
#  'complementation': '캄플러멘테이션',
#  'complementative': '',
#  'complementer': '',
#  'complementoid': '',
#  'complete': '컴플릿',
#  'completedness': '',
#  'completely': '컴플릿리',
#  'completement': '',
#  'completeness': '컴플릿니스',
#  'completer': '',
#  'completion': '컴플리션',
#  'completive': '컴플리티브',
#  'completively': '',
#  'completory': '',
#  'complex': '컴플렉스',
#  'complexedness': '',
#  'complexification': '',
#  'complexify': '',
#  'complexion': '컴플렉션',
#  'complexionably': '',
#  'complexional': '컴플렉셔널',
#  'complexionally': '',
#  'complexioned': '컴플렉션드',
#  'complexionist': '',
#  'complexionless': '컴플렉션리스',
#  'complexity': '컴플렉서티',
#  'complexively': '',
#  'complexly': '컴플렉슬리',
#  'complexness': '컴플렉스니스',
#  'complexus': '',
#  'compliable': '컴플라이어블',
#  'compliableness': '',
#  'compliably': '',
#  'compliance': '컴플라이언스',
#  'compliancy': '',
#  'compliant': '컴플라이언트',
#  'compliantly': '컴플라이언틀리',
#  'complicacy': '캄플러커시',
#  'complicant': '',
#  'complicate': '캄플러케이트',
#  'complicated': '캄플러케이티드',
#  'complicatedly': '',
#  'complicatedness': '',
#  'complication': '캄플러케이션',
#  'complicative': '',
#  'complice': '캄플러스',
#  'complicitous': '',
#  'complicity': '컴플리서티',
#  'complier': '컴플라이어',
#  'compliment': '캄플러먼트',
#  'complimentable': '',
#  'complimental': '',
#  'complimentally': '',
#  'complimentalness': '',
#  'complimentarily': '',
#  'complimentariness': '',
#  'complimentary': '캄플러멘터리',
#  'complimentation': '',
#  'complimentative': '',
#  'complimenter': '캄플러먼터',
#  'complimentingly': '',
#  'complin': '캄플린',
#  'complot': '캄플랏',
#  'complotter': '컴플라터',
#  'Complutensian': '',
#  'compluvium': '',
#  'comply': '컴플라이',
#  'compo': '캄포',
#  'compoer': '',
#  'compole': '',
#  'compone': '',
#  'componed': '',
#  'componency': '',
#  'componendo': '',
#  'component': '컴포넌트',
#  'componental': '',
#  'componented': '',
#  'compony': '컴포니',
#  'comport': '컴포트',
#  'comportment': '컴포트먼트',
#  'compos': '',
#  'compose': '컴포즈',
#  'composed': '컴포즈드',
#  'composedly': '컴포지들리',
#  'composedness': '컴포지드니스',
#  'composer': '컴포저',
#  'composita': '',
#  'Compositae': '',
#  'composite': '컴파짓',
#  'compositely': '',
#  'compositeness': '',
#  'composition': '캄퍼지션',
#  'compositional': '',
#  'compositionally': '',
#  'compositive': '컴파지티브',
#  'compositively': '',
#  'compositor': '컴파지터',
#  'compositorial': '',
#  'compositous': '',
#  'composograph': '',
#  'compossibility': '',
#  'compossible': '캄파서블',
#  'compost': '캄포스트',
#  'composture': '',
#  'composure': '컴포저',
#  'compotation': '캄퍼테이션',
#  'compotationship': '',
#  'compotator': '캄퍼테이터',
#  'compotatory': '',
#  'compote': '캄포트',
#  'compotor': '',
#  'compound': '캄파운드',
#  'compoundable': '컴파운더블',
#  'compoundedness': '',
#  'compounder': '컴파운더',
#  'compounding': '',
#  'compoundness': '',
#  'comprachico': '',
#  'comprador': '캄프러도',
#  'comprecation': '',
#  'compreg': '캄프레그',
#  'compregnate': '컴프레그네이트',
#  'comprehend': '캄프리헨드',
#  'comprehender': '',
#  'comprehendible': '',
#  'comprehendingly': '캄프리헨딩리',
#  'comprehense': '',
#  'comprehensibility': '캄프리헨 서빌러티',
#  'comprehensible': '캄프리헨서블',
#  'comprehensibleness': '캄프리헨서블니스',
#  'comprehensibly': '캄프리헨서블리',
#  'comprehension': '캄프리헨션',
#  'comprehensive': '캄프리헨시브',
#  'comprehensively': '캄프리헨시블리',
#  'comprehensiveness': '캄프리헨시브니스',
#  'comprehensor': '',
#  'compresbyter': '',
#  'compresbyterial': '',
#  'compresence': '',
#  'compresent': '',
#  'compress': '컴프레스',
#  'compressed': '컴프레스트',
#  'compressedly': '',
#  'compressibility': '컴프레서빌러티',
#  'compressible': '컴프레서블',
#  'compressibleness': '',
#  'compressingly': '',
#  'compression': '컴프레션',
#  'compressional': '',
#  'compressive': '컴프레시브',
#  'compressively': '',
#  'compressometer': '',
#  'compressor': '컴프레서',
#  'compressure': '컴프레셔',
#  'comprest': '',
#  'compriest': '',
#  'comprisable': '',
#  'comprisal': '컴프라이절',
#  'comprise': '컴프라이즈',
#  'comprised': '',
#  'compromise': '캄프러마이즈',
#  'compromiser': '캄프러마이저',
#  'compromising': '캄프러마이징',
#  'compromisingly': '',
#  'compromissary': '',
#  'compromission': '',
#  'compromissorial': '',
#  'compromit': '',
#  'compromitment': '',
#  'comprovincial': '캄프러빈셜',
#  'Compsilura': '',
#  'Compsoa': '',
#  'Compsognathus': '',
#  'Compsothlypidae': '',
#  'compter': '',
#  'Comptometer': '캄프타미터',
#  'Comptonia': '',
#  'comptroller': '컨트롤러',
#  'comptrollership': '',
#  'compulsative': '',
#  'compulsatively': '',
#  'compulsatorily': '',
#  'compulsatory': '',
#  'compulsed': '',
#  'compulsion': '컴펄션',
#  'compulsitor': '',
#  'compulsive': '컴펄시브',
#  'compulsively': '컴펄시블리',
#  'compulsiveness': '',
#  'compulsorily': '컴펄서릴리',
#  'compulsoriness': '',
#  'compulsory': '컴펄서리',
#  'compunction': '컴펑크션',
#  'compunctionary': '',
#  'compunctionless': '',
#  'compunctious': '컴펑크셔스',
#  'compunctiously': '컴펑크셔슬리',
#  'compunctive': '',
#  'compurgation': '캄퍼게이션',
#  'compurgator': '캄퍼게이터',
#  'compurgatorial': '',
#  'compurgatory': '',
#  'compursion': '',
#  'computability': '',
#  'computable': '컴퓨터블',
#  'computably': '',
#  'computation': '캄퓨테이션',
#  'computational': '캄퓨테이셔널',
#  'computative': '캄퓨테이티브',
#  'computativeness': '',
#  'compute': '컴퓨트',
#  'computer': '컴퓨터',
#  'computist': '컴퓨티스트',
#  'computus': '',
#  'comrade': '캄래드',
#  'comradely': '캄래들리',
#  'comradery': '캄래드리',
#  'comradeship': '캄래드쉽',
#  'Comsomol': '',
#  'comstockery': '컴스타커리',
#  'Comtian': '',
#  'Comtism': '',
#  'Comtist': '',
#  'comurmurer': '',
#  'Comus': '코머스',
#  'con': '칸',
#  'conacaste': '',
#  'conacre': '카네이커',
#  'conal': '',
#  'conalbumin': '',
#  'conamed': '',
#  'Conant': '',
#  'conarial': '',
#  'conarium': '',
#  'conation': '코네이션',
#  'conational': '',
#  'conationalistic': '',
#  'conative': '카너티브',
#  'conatus': '코네이터스',
#  'conaxial': '',
#  'concamerate': '',
#  'concamerated': '',
#  'concameration': '',
#  'concanavalin': '',
#  'concaptive': '',
#  'concassation': '',
#  'concatenary': '',
#  'concatenate': '칸캐터네이트',
#  'concatenation': '칸캐터네이션',
#  'concatenator': '',
#  'concausal': '',
#  'concause': '',
#  'concavation': '',
#  'concave': '칸케이브',
#  'concavely': '',
#  'concaveness': '칸케이브니스',
#  'concaver': '',
#  'concavity': '칸캐버티',
#  'conceal': '컨실',
#  'concealable': '컨실러블',
#  'concealed': '',
#  'concealedly': '',
#  'concealedness': '',
#  'concealer': '컨실러',
#  'concealment': '컨실먼트',
#  'concede': '컨시드',
#  'conceded': '',
#  'concededly': '컨시디들리',
#  'conceder': '',
#  'conceit': '컨싯',
#  'conceited': '컨시티드',
#  'conceitedly': '컨시티들리',
#  'conceitedness': '컨시티드니스',
#  'conceitless': '',
#  'conceity': '',
#  'conceivability': '',
#  'conceivable': '컨시버블',
#  'conceivableness': '',
#  'conceivably': '컨시버블리',
#  'conceive': '컨시브',
#  'conceiver': '컨시버',
#  'concelebrate': '컨셀러브레이트',
#  'concelebration': '',
#  'concent': '컨센트',
#  'concenter': '칸센터',
#  'concentive': '',
#  'concentralization': '',
#  'concentrate': '칸선트레이트',
#  'concentrated': '칸선트레이티드',
#  'concentration': '칸선트레이션',
#  'concentrative': '칸선트레이티브',
#  'concentrativeness': '칸선트레이티브니스',
#  'concentrator': '칸선트레이터',
#  'concentric': '컨센트릭',
#  'concentrically': '컨센트리컬리',
#  'concentricity': '칸센트리서티',
#  'concentual': '',
#  'concentus': '',
#  'concept': '칸셉트',
#  'conceptacle': '컨셉터클',
#  'conceptacular': '',
#  'conceptaculum': '',
#  'conception': '컨셉션',
#  'conceptional': '컨셉셔널',
#  'conceptionist': '',
#  'conceptism': '',
#  'conceptive': '컨셉티브',
#  'conceptiveness': '',
#  'conceptual': '컨셉추얼',
#  'conceptualism': '컨셉추얼리즘',
#  'conceptualist': '컨셉추얼리스트',
#  'conceptualistic': '',
#  'conceptuality': '',
#  'conceptualization': '컨 셉추얼러제이션',
#  'conceptualize': '컨셉추얼라이즈',
#  'conceptually': '컨셉추얼리',
#  'conceptus': '',
#  'concern': '컨선',
#  'concerned': '컨선드',
#  'concernedly': '컨서니들리',
#  'concernedness': '',
#  'concerning': '컨서닝',
#  'concerningly': '',
#  'concerningness': '',
#  'concernment': '컨선먼트',
#  'concert': '칸서트',
#  'concerted': '컨서티드',
#  'concertedly': '',
#  'concertgoer': '칸서트고어',
#  'concertina': '칸서티너',
#  'concertinist': '',
#  'concertist': '',
#  'concertize': '칸서타이즈',
#  'concertizer': '',
#  'concertmaster': '',
#  'concertmeister': '',
#  'concertment': '',
#  'concerto': '컨체어토',
#  'concertstuck': '',
#  'concessible': '',
#  'concession': '컨세션',
#  'concessionaire': '컨세셔네어',
#  'concessional': '',
#  'concessionary': '컨세셔네리',
#  'concessioner': '컨세셔너',
#  'concessionist': '',
#  'concessive': '컨세시브',
#  'concessively': '',
#  'concessiveness': '',
#  'concessor': '',
#  'concettism': '컨체티즘',
#  'concettist': '',
#  'conch': '캉크',
#  'concha': '캉커',
#  'conchal': '캉컬',
#  'conchate': '',
#  'conche': '',
#  'conched': '',
#  'concher': '',
#  'Conchifera': '',
#  'conchiferous': '캉키퍼러스',
#  'conchiform': '',
#  'conchinine': '',
#  'conchiolin': '캉카이얼린',
#  'conchitic': '',
#  'conchitis': '',
#  'Conchobor': '',
#  'conchoid': '캉코이드',
#  'conchoidal': '캉코이들',
#  'conchoidally': '',
#  'conchological': '캉컬라지컬',
#  'conchologically': '',
#  'conchologist': '캉칼러지스트',
#  'conchologize': '',
#  'conchology': '캉칼러지',
#  'conchometer': '',
#  'conchometry': '',
#  'Conchostraca': '',
#  'conchotome': '',
#  'Conchubar': '',
#  'Conchucu': '',
#  'conchuela': '',
#  'conchy': '',
#  'conchyliated': '',
#  'conchyliferous': '',
#  'conchylium': '',
#  'concierge': '칸시에어지',
#  'concile': '',
#  'conciliable': '컨실리어블',
#  'conciliabule': '',
#  'conciliabulum': '',
#  'conciliar': '컨실리어',
#  'conciliate': '컨실리에이트',
#  'conciliating': '',
#  'conciliatingly': '',
#  'conciliation': '컨실리에이션',
#  'conciliationist': '',
#  'conciliative': '컨실리에이티브',
#  'conciliator': '컨실리에이터',
#  'conciliatorily': '',
#  'conciliatoriness': '',
#  'conciliatory': '컨실리어토리',
#  'concilium': '',
#  'concinnity': '컨시너티',
#  'concinnous': '컨시너스',
#  'concionator': '',
#  'concipiency': '',
#  'concipient': '',
#  'concise': '컨사이스',
#  'concisely': '컨사이슬리',
#  'conciseness': '컨사이스니스',
#  'concision': '컨시전',
#  'conclamant': '',
#  'conclamation': '',
#  'conclave': '칸클레이브',
#  'conclavist': '칸클레이비스트',
#  'concludable': '',
#  'conclude': '컨클룻',
#  'concluder': '컨클루더',
#  'concluding': '',
#  'concludingly': '',
#  'conclusion': '컨클루전',
#  'conclusional': '',
#  'conclusionally': '',
#  'conclusive': '컨클루시브',
#  'conclusively': '컨클루시블리',
#  'conclusiveness': '컨클루시브니스',
#  'conclusory': '컨클루서리',
#  'concoagulate': '',
#  'concoagulation': '',
#  'concoct': '칸칵트',
#  'concocter': '컨칵터',
#  'concoction': '칸칵션',
#  'concoctive': '칸칵티브',
#  'concoctor': '',
#  'concolor': '',
#  'concolorous': '칸컬러러스',
#  'concomitance': '칸카미턴스',
#  'concomitancy': '',
#  'concomitant': '칸카머턴트',
#  'concomitantly': '칸카머턴틀리',
#  'conconscious': '',
#  'Concord': '칸코드',
#  'concord': '칸코드',
#  'concordal': '',
#  'concordance': '칸코던스',
#  'concordancer': '',
#  'concordant': '칸코던트',
#  'concordantial': '',
#  'concordantly': '칸코던틀리',
#  'concordat': '칸코댓',
#  'concordatory': '',
#  'concorder': '',
#  'concordial': '',
#  'concordist': '',
#  'concordity': '',
#  'concorporate': '',
#  'Concorrezanes': '',
#  'concourse': '칸코스',
#  'concreate': '',
#  'concremation': '',
#  'concrement': '',
#  'concresce': '',
#  'concrescence': '칸크레슨스',
#  'concrescible': '',
#  'concrescive': '',
#  'concrete': '칸크릿',
#  'concretely': '칸크릿리',
#  'concreteness': '칸크릿니스',
#  'concreter': '',
#  'concretion': '칸크리션',
#  'concretional': '',
#  'concretionary': '칸크리셔네리',
#  'concretism': '칸크리티즘',
#  'concretive': '칸크리티브',
#  'concretively': '칸크리티블리',
#  'concretize': '칸크러타이즈',
#  'concretor': '',
#  'concubinage': '칸큐버니지',
#  'concubinal': '',
#  'concubinarian': '',
#  'concubinary': '칸큐버네리',
#  'concubinate': '',
#  'concubine': '캉큐바인',
#  'concubinehood': '',
#  'concubitancy': '',
#  'concubitant': '',
#  'concubitous': '',
#  'concubitus': '',
#  'concupiscence': '칸큐퍼선스',
#  'concupiscent': '칸큐피선트',
#  'concupiscible': '칸큐퍼서블',
#  'concupiscibleness': '',
#  'concupy': '',
#  'concur': '컨커',
#  'concurrence': '컨커런스',
#  'concurrency': '',
#  'concurrent': '컨커런트',
#  'concurrently': '컨커런틀리',
#  'concurrentness': '',
#  'concurring': '',
#  'concurringly': '',
#  'concursion': '',
#  'concurso': '',
#  'concursus': '',
#  'concuss': '컨커스',
#  'concussant': '',
#  'concussion': '컨커션',
#  'concussional': '',
#  'concussive': '컨커시브',
#  'concutient': '',
#  'concyclic': '컨사이클릭',
#  'concyclically': '',
#  'cond': '',
#  'Condalia': '',
#  'condemn': '컨뎀',
#  'condemnable': '컨뎀너블',
#  'condemnably': '',
#  'condemnate': '',
#  'condemnation': '칸뎀네이션',
#  'condemnatory': '컨뎀너토리',
#  'condemned': '컨뎀드',
#  'condemner': '컨뎀너',
#  'condemning': '',
#  'condemningly': '',
#  'condensability': '컨덴서빌러티',
#  'condensable': '컨덴서블',
#  'condensance': '',
#  'condensary': '',
#  'condensate': '컨덴세이트',
#  'condensation': '칸덴세이션',
#  'condensational': '',
#  'condensative': '',
#  'condensator': '',
#  'condense': '컨덴스',
#  'condensed': '컨덴스트',
#  'condensedly': '',
#  'condensedness': '',
#  'condenser': '컨덴서',
#  'condensery': '컨덴서리',
#  'condensity': '',
#  'condescend': '칸더센드',
#  'condescendence': '칸디센든스',
#  'condescendent': '',
#  'condescender': '',
#  'condescending': '칸더센딩',
#  'condescendingly': '칸더센딩리',
#  'condescendingness': '',
#  'condescension': '칸더센션',
#  'condescensive': '',
#  'condescensively': '',
#  'condescensiveness': '',
#  'condiction': '',
#  'condictious': '',
#  'condiddle': '',
#  'condiddlement': '',
#  'condign': '컨다인',
#  'condigness': '',
#  'condignity': '',
#  'condignly': '컨다인리',
#  'condiment': '칸더먼트',
#  'condimental': '',
#  'condimentary': '',
#  'condisciple': '칸디사이펄',
#  'condistillation': '',
#  'condite': '',
#  'condition': '컨디션',
#  'conditional': '컨디셔널',
#  'conditionalism': '',
#  'conditionalist': '',
#  'conditionality': '컨디셔낼러티',
#  'conditionalize': '',
#  'conditionally': '컨디셔널리',
#  'conditionate': '',
#  'conditioned': '컨디션드',
#  'conditioner': '컨디셔너',
#  'condivision': '',
#  'condolatory': '컨돌러토리',
#  'condole': '컨돌',
#  'condolement': '컨돌먼트',
#  'condolence': '컨돌런스',
#  'condolent': '컨돌런트',
#  'condoler': '컨돌러',
#  'condoling': '',
#  'condolingly': '',
#  'condominate': '칸다머넛',
#  'condominium': '칸더미니엄',
#  'condonable': '',
#  'condonance': '',
#  'condonation': '칸도네이션',
#  'condonative': '',
#  'condone': '컨돈',
#  'condonement': '',
#  'condoner': '',
#  'condor': '칸더',
#  'conduce': '컨듀스',
#  'conducer': '',
#  'conducing': '',
#  'conducingly': '',
#  'conducive': '컨듀시브',
#  'conduciveness': '',
#  'conduct': '칸덕트',
#  'conductance': '컨덕턴스',
#  'conductibility': '컨덕터빌러티',
#  'conductible': '컨덕터블',
#  'conductility': '',
#  'conductimeter': '',
#  'conductio': '',
#  'conduction': '컨덕션',
#  'conductional': '',
#  'conductitious': '',
#  'conductive': '컨덕티브',
#  'conductively': '',
#  'conductivity': '칸덕티버티',
#  'conductometer': '',
#  'conductometric': '컨덕터메트릭',
#  'conductor': '컨덕터',
#  'conductorial': '',
#  'conductorless': '',
#  'conductorship': '',
#  'conductory': '',
#  'conductress': '컨덕트러스',
#  'conductus': '',
#  'conduit': '칸드윗',
#  'conduplicate': '칸듀플러킷',
#  'conduplicated': '',
#  'conduplication': '',
#  'condurangin': '',
#  'condurango': '',
#  'condylar': '칸다일러',
#  'condylarth': '',
#  'Condylarthra': '',
#  'condylarthrosis': '',
#  'condylarthrous': '',
#  'condyle': '칸다일',
#  'condylectomy': '',
#  'condylion': '',
#  'condyloid': '칸덜로이드',
#  'condyloma': '칸덜로머',
#  'condylomatous': '',
#  'condylome': '',
#  'condylopod': '',
#  'Condylopoda': '',
#  'condylopodous': '',
#  'condylos': '',
#  'condylotomy': '',
#  'Condylura': '',
#  ...}
